# %%
#fear emotion

#데이터 pandas로 읽기, 구문이 탭으로 구분되어있음.
import pandas as pd
train_fear_df = pd.read_csv("feartrainalldata.txt","\t") 
test_fear_df = pd.read_csv("feartestalldata.txt","\t")

#konlpy는 띄어쓰기 알고리즘과 정규화를 이용해 맞춤법이 틀린 문장을 고치고 형태소 분석과 품사를 태깅해주는 클래스를 제공함.
from konlpy.tag import Okt
okt_fear = Okt()

def fear_tokenize(doc):
    return ['/'.join(t) for t in okt_fear.pos(doc, norm=True, stem=True)] 
    #'구분자'.join(list) => 리스트 값과 값 사이에 구분자를 넣어 문자열을 하나로 합침. ex) '_'.join(['a','b','c'])이면 "a_b_c"로 반환
    #pos(text) => 품사를 태깅한 상태로 명사를 변환, ex) 컴퓨터(x), 컵퓨터,noun(o)
    #norm => 정규화 ex) 그래욬ㅋㅋㅋ => 그래요
    #stem => 근어로 표현 ex) 그래요 => 그렇다

train_fear_df.isnull().any()
train_fear_df['document'] = train_fear_df['document'].fillna(''); #null값을 ''로 대체
test_fear_df.isnull().any()
test_fear_df['document'] = test_fear_df['document'].fillna('');

train_fear_docs = [(fear_tokenize(row[1]), row[2]) for row in train_fear_df.values] #traindata 저장 row[1] : document / row[2] : label
test_fear_docs = [(fear_tokenize(row[1]),row[2]) for row in test_fear_df.values] #testdata 저장

tokens = [t for d in train_fear_docs for t in d[0]]

import nltk
fear_text = nltk.Text(tokens, name='FEAR') 
#문서 하나를 편리하게 탐색할 수 있는 기능 제공 (vocab().most_common() 사용)
# print(len(fear_text.tokens)) #토큰 개수
# print(len(set(fear_text.tokens))) #중복을 제외한 토큰 수
# print(fear_text.vocab().most_common(10)) #출력빈도가 높은 상위 토큰 10개

#countvectorization
FEAR_FREQUENCY_COUNT = 3000; #자주 사용되는 토큰 설정
fear_selected_words = [f[0] for f in fear_text.vocab().most_common(FEAR_FREQUENCY_COUNT)] #선택되어진 토큰들

def fear_term_frequency(doc):
    return [doc.count(word) for word in fear_selected_words]

x_fear_train = [fear_term_frequency(d) for d,_ in train_fear_docs]
x_fear_test = [fear_term_frequency(d) for d,_ in test_fear_docs]
#x축에는 문서에 들어가는 단어 개수(단어들의 빈도수 정보)

y_fear_train = [c for _,c in train_fear_docs]
y_fear_test = [c for _,c in test_fear_docs]
#y축에는 1 or 0, 분류 결과

import numpy as np
x_fear_train = np.asarray(x_fear_train).astype('float32')
x_fear_test = np.asarray(x_fear_test). astype('float32')

y_fear_train = np.asarray(y_fear_train).astype('float32')
y_fear_test = np.asarray(y_fear_test).astype('float32')
#np.asarray는 np.array와 달리 데이터 형태가 같을 때 복사하지 않음.
#데이터 float로 형 변환

import tensorflow as tf #텐서플로 케라스
fear_model= tf.keras.models.Sequential([
    tf.keras.layers.Dense(64, activation = 'relu',input_shape=(FEAR_FREQUENCY_COUNT,)),
    tf.keras.layers.Dense(64, activation = 'relu'),
    tf.keras.layers.Dense(1, activation = 'sigmoid')
])
#레이어 구성은 dense층은 64개의 유닛, 활성함수는 relu, 마지막 층은 sigmoid 활성화 함수 사용

fear_model.compile(optimizer=tf.keras.optimizers.RMSprop(lr=0.001),
             loss=tf.keras.losses.binary_crossentropy,
             metrics=[tf.keras.metrics.binary_accuracy]
             )
#손실 함수는 binary_crossentropy, RMSprop 옵티마이저를 통해 경사하강법 진행

fear_model.fit(x_fear_train, y_fear_train, epochs=50, batch_size=512)
#배치 사이즈 줄이면 한 번에 판단하는 데이터 수 증가함. 에포크 50번
fear_results = fear_model.evaluate(x_fear_test, y_fear_test)

fear_review = "너무 무섭다"
fear_token = fear_tokenize(fear_review)

fear_tf = fear_term_frequency(fear_token)
f_data = np.expand_dims(np.asarray(fear_tf).astype('float32'),axis=0)
float(fear_model.predict(f_data))

#surprise emotion

import pandas as pd
train_surprise_df = pd.read_csv("surprisetrainalldata.txt","\t")
test_surprise_df = pd.read_csv("surprisetestalldata.txt","\t")

from konlpy.tag import Okt
okt_surprise = Okt()

def surprise_tokenize(doc):
    return ['/'.join(t) for t in okt_surprise.pos(doc, norm=True, stem=True)]

train_surprise_df.isnull().any()
train_surprise_df['document'] = train_surprise_df['document'].fillna('');
test_surprise_df.isnull().any()
test_surprise_df['document'] = test_surprise_df['document'].fillna('');

train_surprise_docs = [(surprise_tokenize(row[1]), row[2]) for row in train_surprise_df.values]
test_surprise_docs = [(surprise_tokenize(row[1]),row[2]) for row in test_surprise_df.values]

tokens = [t for d in train_surprise_docs for t in d[0]]

import nltk
surprise_text = nltk.Text(tokens, name='SURP')
#print(len(surprise_text.tokens))
#print(len(set(surprise_text.tokens)))
#print(surprise_text.vocab().most_common(10))

SURPRISE_FREQUENCY_COUNT = 3000; #variable
surprise_selected_words = [f[0] for f in surprise_text.vocab().most_common(SURPRISE_FREQUENCY_COUNT)]

def surprise_term_frequency(doc):
    return [doc.count(word) for word in surprise_selected_words]

x_surprise_train = [surprise_term_frequency(d) for d,_ in train_surprise_docs]
x_surprise_test = [surprise_term_frequency(d) for d,_ in test_surprise_docs]
y_surprise_train = [c for _,c in train_surprise_docs]
y_surprise_test = [c for _,c in test_surprise_docs]

import numpy as np
x_surprise_train = np.asarray(x_surprise_train).astype('float32')
x_surprise_test = np.asarray(x_surprise_test). astype('float32')

y_surprise_train = np.asarray(y_surprise_train).astype('float32')
y_surprise_test = np.asarray(y_surprise_test).astype('float32')

import tensorflow as tf
surprise_model= tf.keras.models.Sequential([
    tf.keras.layers.Dense(64, activation = 'relu',input_shape=(SURPRISE_FREQUENCY_COUNT,)),
    tf.keras.layers.Dense(64, activation = 'relu'),
    tf.keras.layers.Dense(1, activation = 'sigmoid')
])

surprise_model.compile(optimizer=tf.keras.optimizers.RMSprop(lr=0.001),
             loss=tf.keras.losses.binary_crossentropy,
             metrics=[tf.keras.metrics.binary_accuracy]
             )

surprise_model.fit(x_surprise_train, y_surprise_train, epochs=50, batch_size=512)
surprise_results = surprise_model.evaluate(x_surprise_test, y_surprise_test)
surprise_review = "너무 놀랍다"
surprise_token = surprise_tokenize(surprise_review)

tf = surprise_term_frequency(surprise_token)
data = np.expand_dims(np.asarray(tf).astype('float32'),axis=0)
float(surprise_model.predict(data))

#anger emotion

import pandas as pd
train_anger_df = pd.read_csv("angertrainalldata.txt","\t")
test_anger_df = pd.read_csv("angertestalldata.txt","\t")

from konlpy.tag import Okt
okt_anger = Okt()

def anger_tokenize(doc):
    return ['/'.join(t) for t in okt_anger.pos(doc, norm=True, stem=True)]

train_anger_df.isnull().any()
train_anger_df['document'] = train_anger_df['document'].fillna('');
test_anger_df.isnull().any()
test_anger_df['document'] = test_anger_df['document'].fillna('');

train_anger_docs = [(anger_tokenize(row[1]), row[2]) for row in train_anger_df.values]
test_anger_docs = [(anger_tokenize(row[1]),row[2]) for row in test_anger_df.values]

tokens = [t for d in train_anger_docs for t in d[0]]

import nltk
anger_text = nltk.Text(tokens, name='ANGE')
#print(len(anger_text.tokens))
#print(len(set(anger_text.tokens)))
#print(anger_text.vocab().most_common(10))

ANGER_FREQUENCY_COUNT = 3000; #variable
anger_selected_words = [f[0] for f in anger_text.vocab().most_common(ANGER_FREQUENCY_COUNT)]

def anger_term_frequency(doc):
    return [doc.count(word) for word in anger_selected_words]

x_anger_train = [anger_term_frequency(d) for d,_ in train_anger_docs]
x_anger_test = [anger_term_frequency(d) for d,_ in test_anger_docs]
y_anger_train = [c for _,c in train_anger_docs]
y_anger_test = [c for _,c in test_anger_docs]

import numpy as np
x_anger_train = np.asarray(x_anger_train).astype('float32')
x_anger_test = np.asarray(x_anger_test). astype('float32')

y_anger_train = np.asarray(y_anger_train).astype('float32')
y_anger_test = np.asarray(y_anger_test).astype('float32')

import tensorflow as tf
anger_model= tf.keras.models.Sequential([
    tf.keras.layers.Dense(64, activation = 'relu',input_shape=(ANGER_FREQUENCY_COUNT,)),
    tf.keras.layers.Dense(64, activation = 'relu'),
    tf.keras.layers.Dense(1, activation = 'sigmoid')
])

anger_model.compile(optimizer=tf.keras.optimizers.RMSprop(lr=0.001),
             loss=tf.keras.losses.binary_crossentropy,
             metrics=[tf.keras.metrics.binary_accuracy]
             )

anger_model.fit(x_anger_train, y_anger_train, epochs=50, batch_size=512)
anger_results = anger_model.evaluate(x_anger_test, y_anger_test)

anger_review = "너무 화난다"
anger_token = anger_tokenize(anger_review)

tf = anger_term_frequency(anger_token)
data = np.expand_dims(np.asarray(tf).astype('float32'),axis=0)
float(anger_model.predict(data))

#sadness emotion

import pandas as pd
train_sadness_df = pd.read_csv("sadnesstrainalldata.txt","\t")
test_sadness_df = pd.read_csv("sadnesstestalldata.txt","\t")

from konlpy.tag import Okt
okt_sadness = Okt()

def sadness_tokenize(doc):
    return ['/'.join(t) for t in okt_sadness.pos(doc, norm=True, stem=True)]

train_sadness_df.isnull().any()
train_sadness_df['document'] = train_sadness_df['document'].fillna('');
test_sadness_df.isnull().any()
test_sadness_df['document'] = test_sadness_df['document'].fillna('');

train_sadness_docs = [(sadness_tokenize(row[1]), row[2]) for row in train_sadness_df.values]
test_sadness_docs = [(sadness_tokenize(row[1]),row[2]) for row in test_sadness_df.values]

tokens = [t for d in train_sadness_docs for t in d[0]]

import nltk
sadness_text = nltk.Text(tokens, name='SADN')
#print(len(sadness_text.tokens))
#print(len(set(sadness_text.tokens)))
#print(sadness_text.vocab().most_common(10))

SADNESS_FREQUENCY_COUNT = 3000; #variable
sadness_selected_words = [f[0] for f in fear_text.vocab().most_common(SADNESS_FREQUENCY_COUNT)]

def sadness_term_frequency(doc):
    return [doc.count(word) for word in sadness_selected_words]

x_sadness_train = [sadness_term_frequency(d) for d,_ in train_sadness_docs]
x_sadness_test = [sadness_term_frequency(d) for d,_ in test_sadness_docs]
y_sadness_train = [c for _,c in train_sadness_docs]
y_sadness_test = [c for _,c in test_sadness_docs]

import numpy as np
x_sadness_train = np.asarray(x_sadness_train).astype('float32')
x_sadness_test = np.asarray(x_sadness_test). astype('float32')

y_sadness_train = np.asarray(y_sadness_train).astype('float32')
y_sadness_test = np.asarray(y_sadness_test).astype('float32')

import tensorflow as tf
sadness_model= tf.keras.models.Sequential([
    tf.keras.layers.Dense(64, activation = 'relu',input_shape=(SADNESS_FREQUENCY_COUNT,)),
    tf.keras.layers.Dense(64, activation = 'relu'),
    tf.keras.layers.Dense(1, activation = 'sigmoid')
])

sadness_model.compile(optimizer=tf.keras.optimizers.RMSprop(lr=0.001),
             loss=tf.keras.losses.binary_crossentropy,
             metrics=[tf.keras.metrics.binary_accuracy]
             )

sadness_model.fit(x_sadness_train, y_sadness_train, epochs=50, batch_size=512)
sadness_results = sadness_model.evaluate(x_sadness_test, y_sadness_test)
sadness_review = "너무 화난다"
sadness_token = sadness_tokenize(sadness_review)

tf = sadness_term_frequency(sadness_token)
data = np.expand_dims(np.asarray(tf).astype('float32'),axis=0)
float(sadness_model.predict(data))

#neutral emotion

import pandas as pd
train_neutral_df = pd.read_csv("neutraltrainalldata.txt","\t")
test_neutral_df = pd.read_csv("neutraltestalldata.txt","\t")

from konlpy.tag import Okt
okt_neutral = Okt()

def neutral_tokenize(doc):
    return ['/'.join(t) for t in okt_neutral.pos(doc, norm=True, stem=True)]

train_neutral_df.isnull().any()
train_neutral_df['document'] = train_neutral_df['document'].fillna('');
test_neutral_df.isnull().any()
test_neutral_df['document'] = test_neutral_df['document'].fillna('');

train_neutral_docs = [(neutral_tokenize(row[1]), row[2]) for row in train_neutral_df.values]
test_neutral_docs = [(neutral_tokenize(row[1]),row[2]) for row in test_neutral_df.values]

tokens = [t for d in train_neutral_docs for t in d[0]]

import nltk
neutral_text = nltk.Text(tokens, name='NEUT')
#print(len(neutral_text.tokens))
#print(len(set(neutral_text.tokens)))
#print(neutral_text.vocab().most_common(10))

NEUTRAL_FREQUENCY_COUNT = 3000; #variable
neutral_selected_words = [f[0] for f in neutral_text.vocab().most_common(NEUTRAL_FREQUENCY_COUNT)]

def neutral_term_frequency(doc):
    return [doc.count(word) for word in neutral_selected_words]

x_neutral_train = [neutral_term_frequency(d) for d,_ in train_neutral_docs]
x_neutral_test = [neutral_term_frequency(d) for d,_ in test_neutral_docs]
y_neutral_train = [c for _,c in train_neutral_docs]
y_neutral_test = [c for _,c in test_neutral_docs]

import numpy as np
x_neutral_train = np.asarray(x_neutral_train).astype('float32')
x_neutral_test = np.asarray(x_neutral_test). astype('float32')

y_neutral_train = np.asarray(y_neutral_train).astype('float32')
y_neutral_test = np.asarray(y_neutral_test).astype('float32')

import tensorflow as tf
neutral_model= tf.keras.models.Sequential([
    tf.keras.layers.Dense(64, activation = 'relu',input_shape=(NEUTRAL_FREQUENCY_COUNT,)),
    tf.keras.layers.Dense(64, activation = 'relu'),
    tf.keras.layers.Dense(1, activation = 'sigmoid')
])

neutral_model.compile(optimizer=tf.keras.optimizers.RMSprop(lr=0.001),
             loss=tf.keras.losses.binary_crossentropy,
             metrics=[tf.keras.metrics.binary_accuracy]
             )

neutral_model.fit(x_neutral_train, y_neutral_train, epochs=50, batch_size=512)
neutral_results = neutral_model.evaluate(x_neutral_test, y_neutral_test)
neutral_review = "너무 화난다"
neutral_token = neutral_tokenize(neutral_review)

tf = neutral_term_frequency(neutral_token)
data = np.expand_dims(np.asarray(tf).astype('float32'),axis=0)
float(neutral_model.predict(data))

# happy emotion

import pandas as pd
train_happy_df = pd.read_csv("happytrainalldata.txt","\t")
test_happy_df = pd.read_csv("happytestalldata.txt","\t")

from konlpy.tag import Okt
okt_happy = Okt()

def happy_tokenize(doc):
    return ['/'.join(t) for t in okt_happy.pos(doc, norm=True, stem=True)]

train_happy_df.isnull().any()
train_happy_df['document'] = train_happy_df['document'].fillna('');
test_happy_df.isnull().any()
test_happy_df['document'] = test_happy_df['document'].fillna('');

train_happy_docs = [(happy_tokenize(row[1]), row[2]) for row in train_happy_df.values]
test_happy_docs = [(happy_tokenize(row[1]),row[2]) for row in test_happy_df.values]

tokens = [t for d in train_happy_docs for t in d[0]]

import nltk
happy_text = nltk.Text(tokens, name='HAPP')
#print(len(happy_text.tokens))
#print(len(set(happy_text.tokens)))
#print(happy_text.vocab().most_common(10))

HAPPY_FREQUENCY_COUNT = 3000; #variable
happy_selected_words = [f[0] for f in happy_text.vocab().most_common(HAPPY_FREQUENCY_COUNT)]

def happy_term_frequency(doc):
    return [doc.count(word) for word in happy_selected_words]

x_happy_train = [happy_term_frequency(d) for d,_ in train_happy_docs]
x_happy_test = [happy_term_frequency(d) for d,_ in test_happy_docs]
y_happy_train = [c for _,c in train_happy_docs]
y_happy_test = [c for _,c in test_happy_docs]

import numpy as np
x_happy_train = np.asarray(x_happy_train).astype('float32')
x_happy_test = np.asarray(x_happy_test). astype('float32')

y_happy_train = np.asarray(y_happy_train).astype('float32')
y_happy_test = np.asarray(y_happy_test).astype('float32')

import tensorflow as tf
happy_model= tf.keras.models.Sequential([
    tf.keras.layers.Dense(64, activation = 'relu',input_shape=(HAPPY_FREQUENCY_COUNT,)),
    tf.keras.layers.Dense(64, activation = 'relu'),
    tf.keras.layers.Dense(1, activation = 'sigmoid')
])
happy_model.compile(optimizer=tf.keras.optimizers.RMSprop(lr=0.001),
             loss=tf.keras.losses.binary_crossentropy,
             metrics=[tf.keras.metrics.binary_accuracy]
             )

happy_model.fit(x_happy_train, y_happy_train, epochs=50, batch_size=512)
happy_results = happy_model.evaluate(x_happy_test, y_happy_test)

happy_review = "너무 화난다"
happy_token = happy_tokenize(happy_review)

tf = happy_term_frequency(happy_token)
data = np.expand_dims(np.asarray(tf).astype('float32'),axis=0)
float(happy_model.predict(data))

#disgust emotion

import pandas as pd
train_disgust_df = pd.read_csv("disgusttrainalldata.txt","\t")
test_disgust_df = pd.read_csv("disgusttestalldata.txt","\t")

from konlpy.tag import Okt
okt_disgust = Okt()

def disgust_tokenize(doc):
    return ['/'.join(t) for t in okt_disgust.pos(doc, norm=True, stem=True)]

train_disgust_df.isnull().any()
train_disgust_df['document'] = train_disgust_df['document'].fillna('');
test_disgust_df.isnull().any()
test_disgust_df['document'] = test_disgust_df['document'].fillna('');

train_disgust_docs = [(disgust_tokenize(row[1]), row[2]) for row in train_disgust_df.values]
test_disgust_docs = [(disgust_tokenize(row[1]),row[2]) for row in test_disgust_df.values]

tokens = [t for d in train_disgust_docs for t in d[0]]

import nltk
disgust_text = nltk.Text(tokens, name='DISG')
#print(len(disgust_text.tokens))
#print(len(set(disgust_text.tokens)))
#print(disgust_text.vocab().most_common(10))

DISGUST_FREQUENCY_COUNT = 3000; #variable
disgust_selected_words = [f[0] for f in disgust_text.vocab().most_common(DISGUST_FREQUENCY_COUNT)]

def disgust_term_frequency(doc):
    return [doc.count(word) for word in disgust_selected_words]

x_disgust_train = [disgust_term_frequency(d) for d,_ in train_disgust_docs]
x_disgust_test = [disgust_term_frequency(d) for d,_ in test_disgust_docs]
y_disgust_train = [c for _,c in train_disgust_docs]
y_disgust_test = [c for _,c in test_disgust_docs]

import numpy as np
x_disgust_train = np.asarray(x_disgust_train).astype('float32')
x_disgust_test = np.asarray(x_disgust_test). astype('float32')

y_disgust_train = np.asarray(y_disgust_train).astype('float32')
y_disgust_test = np.asarray(y_disgust_test).astype('float32')

import tensorflow as tf
disgust_model= tf.keras.models.Sequential([
    tf.keras.layers.Dense(64, activation = 'relu',input_shape=(DISGUST_FREQUENCY_COUNT,)),
    tf.keras.layers.Dense(64, activation = 'relu'),
    tf.keras.layers.Dense(1, activation = 'sigmoid')
])
disgust_model.compile(optimizer=tf.keras.optimizers.RMSprop(lr=0.001),
             loss=tf.keras.losses.binary_crossentropy,
             metrics=[tf.keras.metrics.binary_accuracy]
             )
disgust_model.fit(x_disgust_train, y_disgust_train, epochs=50, batch_size=512)
disgust_results = neutral_model.evaluate(x_disgust_test, y_disgust_test)
disgust_review = "너무 화난다"
disgust_token = disgust_tokenize(disgust_review)

tf = disgust_term_frequency(disgust_token)
data = np.expand_dims(np.asarray(tf).astype('float32'),axis=0)
float(disgust_model.predict(data))

#function

import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
 
from math import pi
from matplotlib.path import Path
from matplotlib.spines import Spine
from matplotlib.transforms import Affine2D
    
def predict(predict):
    fear_token = fear_tokenize(predict)
    fear_tfq = fear_term_frequency(fear_token)
    fear_data = np.expand_dims(np.asarray(fear_tfq).astype('float32'), axis=0)
    fear_score = float(fear_model.predict(fear_data))
    #print(f"공포({round(fear_score*100)}%)")
    fear = round(fear_score*100)
    surprise_token = surprise_tokenize(predict)
    surprise_tfq = surprise_term_frequency(surprise_token)
    surprise_data = np.expand_dims(np.asarray(surprise_tfq).astype('float32'), axis=0)
    surprise_score = float(surprise_model.predict(surprise_data))
    #print(f"놀람({round(surprise_score*100)}%)")
    surprise = round(surprise_score*100)
    anger_token = anger_tokenize(predict)
    anger_tfq = anger_term_frequency(anger_token)
    anger_data = np.expand_dims(np.asarray(anger_tfq).astype('float32'), axis=0)
    anger_score = float(anger_model.predict(anger_data))
    #print(f"분노({round(anger_score*100)}%)")
    anger = round(anger_score*100)
    sadness_token = sadness_tokenize(predict)
    sadness_tfq = sadness_term_frequency(sadness_token)
    sadness_data = np.expand_dims(np.asarray(sadness_tfq).astype('float32'), axis=0)
    sadness_score = float(sadness_model.predict(sadness_data))
    #print(f"슬픔({round(sadness_score*100)}%)")
    sadness = round(sadness_score*100)
    neutral_token = neutral_tokenize(predict)
    neutral_tfq = neutral_term_frequency(neutral_token)
    neutral_data = np.expand_dims(np.asarray(neutral_tfq).astype('float32'), axis=0)
    neutral_score = float(neutral_model.predict(neutral_data))
    #print(f"중립({round(neutral_score*100)}%)")
    neutral = round(neutral_score*100)
    happy_token = happy_tokenize(predict)
    happy_tfq = happy_term_frequency(happy_token)
    happy_data = np.expand_dims(np.asarray(happy_tfq).astype('float32'), axis=0)
    happy_score = float(happy_model.predict(happy_data))
    #print(f"행복({round(happy_score*100)}%)")
    happy = round(happy_score*100)
    disgust_token = disgust_tokenize(predict)
    disgust_tfq = disgust_term_frequency(disgust_token)
    disgust_data = np.expand_dims(np.asarray(disgust_tfq).astype('float32'), axis=0)
    disgust_score = float(disgust_model.predict(disgust_data))
    #print(f"혐오({round(disgust_score*100)}%)")
    disgust = round(disgust_score*100)
    total = fear+disgust+sadness+happy+anger+neutral+surprise
 
    ## set data
    df = pd.DataFrame({
    'Character': ['RESULT'],
    'Fear': [round(100/(total)*fear)],
    'Disgust': [round(100/(total)*disgust)],
    'Sadness': [round(100/(total)*sadness)],
    'Happy': [round(100/(total)*happy)],
    'Angry': [round(100/(total)*anger)],
    'Neutral': [round(100/(total)*neutral)],
    'Surprise': [round(100/(total)*surprise)],
    })
    labels = df.columns[1:]
    num_labels = len(labels)
    
    angles = [x/float(num_labels)*(2*pi) for x in range(num_labels)] ## 각 등분점
    angles += angles[:1] ## 시작점으로 다시 돌아와야하므로 시작점 추가
    
    my_palette = plt.cm.get_cmap("Set2", len(df.index))
 
    fig = plt.figure(figsize=(15,20))
    fig.set_facecolor('white')
 
    for i, row in df.iterrows():
        color = my_palette(i)
        data = df.iloc[i].drop('Character').tolist()
        data += data[:1]
    
        ax = plt.subplot(3,2,i+1, polar=True)
        ax.set_theta_offset(pi / 2) ## 시작점
        ax.set_theta_direction(-1) ## 그려지는 방향 시계방향
    
        plt.xticks(angles[:-1], labels, fontsize=13) ## x축 눈금 라벨
        ax.tick_params(axis='x', which='major', pad=15) ## x축과 눈금 사이에 여백을 준다.
 
        ax.set_rlabel_position(0) ## y축 각도 설정(degree 단위)
        plt.yticks([0,20,40,60,80,100],['0','20','40','60','80','100'], fontsize=10) ## y축 눈금 설정
        plt.ylim(0,100)
    
        ax.plot(angles, data, color=color, linewidth=2, linestyle='solid') ## 레이더 차트 출력
        ax.fill(angles, data, color=color, alpha=0.4) ## 도형 안쪽에 색을 채워준다.
    
        plt.title(row.Character, size=20, color=color,x=-0.2, y=1.2, ha='left') ## 타이틀은 캐릭터 클래스로 한다.
 
        plt.tight_layout(pad=5) ## subplot간 패딩 조절
        plt.show()

    print(f"공포({round(100/(total)*fear)}%)")
    print(f"혐오({round(100/(total)*disgust)}%)")
    print(f"슬픔({round(100/(total)*sadness)}%)")
    print(f"행복({round(100/(total)*happy)}%)")
    print(f"분노({round(100/(total)*anger)}%)")
    print(f"중립({round(100/(total)*neutral)}%)")
    print(f"놀람({round(100/(total)*surprise)}%)")
# Out:
# Epoch 1/50
# 53/53 [==============================] - 1s 10ms/step - loss: 0.4207 - binary_accuracy: 0.8559
# Epoch 2/50
# 53/53 [==============================] - 0s 8ms/step - loss: 0.3059 - binary_accuracy: 0.8748
# Epoch 3/50
# 53/53 [==============================] - 0s 8ms/step - loss: 0.2727 - binary_accuracy: 0.8890
# Epoch 4/50
# 53/53 [==============================] - 0s 8ms/step - loss: 0.2538 - binary_accuracy: 0.8969
# Epoch 5/50
# 53/53 [==============================] - 0s 8ms/step - loss: 0.2392 - binary_accuracy: 0.9029
# Epoch 6/50
# 53/53 [==============================] - 0s 8ms/step - loss: 0.2246 - binary_accuracy: 0.9107
# Epoch 7/50
# 53/53 [==============================] - 0s 9ms/step - loss: 0.2095 - binary_accuracy: 0.9165
# Epoch 8/50
# 53/53 [==============================] - 0s 8ms/step - loss: 0.1940 - binary_accuracy: 0.9238
# Epoch 9/50
# 53/53 [==============================] - 0s 8ms/step - loss: 0.1778 - binary_accuracy: 0.9330
# Epoch 10/50
# 53/53 [==============================] - 0s 8ms/step - loss: 0.1617 - binary_accuracy: 0.9384
# Epoch 11/50
# 53/53 [==============================] - 0s 8ms/step - loss: 0.1452 - binary_accuracy: 0.9475
# Epoch 12/50
# 53/53 [==============================] - 0s 8ms/step - loss: 0.1296 - binary_accuracy: 0.9539
# Epoch 13/50
# 53/53 [==============================] - 0s 8ms/step - loss: 0.1137 - binary_accuracy: 0.9612
# Epoch 14/50
# 53/53 [==============================] - 0s 8ms/step - loss: 0.0983 - binary_accuracy: 0.9671
# Epoch 15/50
# 53/53 [==============================] - 0s 8ms/step - loss: 0.0842 - binary_accuracy: 0.9724
# Epoch 16/50
# 53/53 [==============================] - 0s 8ms/step - loss: 0.0706 - binary_accuracy: 0.9768
# Epoch 17/50
# 53/53 [==============================] - 0s 8ms/step - loss: 0.0575 - binary_accuracy: 0.9830
# Epoch 18/50
# 53/53 [==============================] - 0s 8ms/step - loss: 0.0471 - binary_accuracy: 0.9857
# Epoch 19/50
# 53/53 [==============================] - 0s 8ms/step - loss: 0.0380 - binary_accuracy: 0.9884
# Epoch 20/50
# 53/53 [==============================] - 0s 8ms/step - loss: 0.0307 - binary_accuracy: 0.9913
# Epoch 21/50
# 53/53 [==============================] - 0s 8ms/step - loss: 0.0247 - binary_accuracy: 0.9929
# Epoch 22/50
# 53/53 [==============================] - 0s 8ms/step - loss: 0.0207 - binary_accuracy: 0.9942
# Epoch 23/50
# 53/53 [==============================] - 0s 9ms/step - loss: 0.0170 - binary_accuracy: 0.9954
# Epoch 24/50
# 53/53 [==============================] - 0s 8ms/step - loss: 0.0146 - binary_accuracy: 0.9957
# Epoch 25/50
# 53/53 [==============================] - 0s 9ms/step - loss: 0.0123 - binary_accuracy: 0.9965
# Epoch 26/50
# 53/53 [==============================] - 0s 8ms/step - loss: 0.0109 - binary_accuracy: 0.9967
# Epoch 27/50
# 53/53 [==============================] - 0s 9ms/step - loss: 0.0103 - binary_accuracy: 0.9966
# Epoch 28/50
# 53/53 [==============================] - 0s 8ms/step - loss: 0.0087 - binary_accuracy: 0.9971
# Epoch 29/50
# 53/53 [==============================] - 0s 8ms/step - loss: 0.0079 - binary_accuracy: 0.9973
# Epoch 30/50
# 53/53 [==============================] - 0s 8ms/step - loss: 0.0077 - binary_accuracy: 0.9971
# Epoch 31/50
# 53/53 [==============================] - 0s 8ms/step - loss: 0.0069 - binary_accuracy: 0.9979
# Epoch 32/50
# 53/53 [==============================] - 0s 8ms/step - loss: 0.0066 - binary_accuracy: 0.9978
# Epoch 33/50
# 53/53 [==============================] - 0s 8ms/step - loss: 0.0064 - binary_accuracy: 0.9979
# Epoch 34/50
# 53/53 [==============================] - 0s 9ms/step - loss: 0.0058 - binary_accuracy: 0.9979
# Epoch 35/50
# 53/53 [==============================] - 0s 8ms/step - loss: 0.0056 - binary_accuracy: 0.9980
# Epoch 36/50
# 53/53 [==============================] - 0s 8ms/step - loss: 0.0055 - binary_accuracy: 0.9979
# Epoch 37/50
# 53/53 [==============================] - 0s 8ms/step - loss: 0.0050 - binary_accuracy: 0.9981
# Epoch 38/50
# 53/53 [==============================] - 0s 9ms/step - loss: 0.0053 - binary_accuracy: 0.9981
# Epoch 39/50
# 53/53 [==============================] - 0s 8ms/step - loss: 0.0051 - binary_accuracy: 0.9980
# Epoch 40/50
# 53/53 [==============================] - 0s 8ms/step - loss: 0.0050 - binary_accuracy: 0.9980
# Epoch 41/50
# 53/53 [==============================] - 0s 8ms/step - loss: 0.0049 - binary_accuracy: 0.9981
# Epoch 42/50
# 53/53 [==============================] - 0s 8ms/step - loss: 0.0045 - binary_accuracy: 0.9981
# Epoch 43/50
# 53/53 [==============================] - 0s 8ms/step - loss: 0.0047 - binary_accuracy: 0.9981
# Epoch 44/50
# 53/53 [==============================] - 0s 8ms/step - loss: 0.0046 - binary_accuracy: 0.9983
# Epoch 45/50
# 53/53 [==============================] - 0s 8ms/step - loss: 0.0047 - binary_accuracy: 0.9980
# Epoch 46/50
# 53/53 [==============================] - 0s 8ms/step - loss: 0.0044 - binary_accuracy: 0.9981
# Epoch 47/50
# 53/53 [==============================] - 0s 8ms/step - loss: 0.0043 - binary_accuracy: 0.9983
# Epoch 48/50
# 53/53 [==============================] - 0s 8ms/step - loss: 0.0044 - binary_accuracy: 0.9983
# Epoch 49/50
# 53/53 [==============================] - 0s 8ms/step - loss: 0.0047 - binary_accuracy: 0.9982
# Epoch 50/50
# 53/53 [==============================] - 0s 8ms/step - loss: 0.0044 - binary_accuracy: 0.9982
# 362/362 [==============================] - 0s 1ms/step - loss: 1.7678 - binary_accuracy: 0.8357A: 0s - loss: 2.3079 - binary_accuracy: 0.7
# Epoch 1/50
# 53/53 [==============================] - 0s 8ms/step - loss: 0.4254 - binary_accuracy: 0.8420
# Epoch 2/50
# 53/53 [==============================] - 0s 7ms/step - loss: 0.3351 - binary_accuracy: 0.8555
# Epoch 3/50
# 53/53 [==============================] - 0s 7ms/step - loss: 0.3014 - binary_accuracy: 0.8722
# Epoch 4/50
# 53/53 [==============================] - 0s 7ms/step - loss: 0.2782 - binary_accuracy: 0.8835
# Epoch 5/50
# 53/53 [==============================] - 0s 7ms/step - loss: 0.2564 - binary_accuracy: 0.8936
# Epoch 6/50
# 53/53 [==============================] - 0s 7ms/step - loss: 0.2354 - binary_accuracy: 0.9034
# Epoch 7/50
# 53/53 [==============================] - 0s 7ms/step - loss: 0.2129 - binary_accuracy: 0.9147
# Epoch 8/50
# 53/53 [==============================] - 0s 7ms/step - loss: 0.1901 - binary_accuracy: 0.9248
# Epoch 9/50
# 53/53 [==============================] - 0s 7ms/step - loss: 0.1672 - binary_accuracy: 0.9364
# Epoch 10/50
# 53/53 [==============================] - 0s 7ms/step - loss: 0.1458 - binary_accuracy: 0.9454
# Epoch 11/50
# 53/53 [==============================] - 0s 7ms/step - loss: 0.1250 - binary_accuracy: 0.9542
# Epoch 12/50
# 53/53 [==============================] - 0s 7ms/step - loss: 0.1065 - binary_accuracy: 0.9616
# Epoch 13/50
# 53/53 [==============================] - 0s 7ms/step - loss: 0.0880 - binary_accuracy: 0.9697
# Epoch 14/50
# 53/53 [==============================] - 0s 7ms/step - loss: 0.0732 - binary_accuracy: 0.9759
# Epoch 15/50
# 53/53 [==============================] - 0s 7ms/step - loss: 0.0596 - binary_accuracy: 0.9806
# Epoch 16/50
# 53/53 [==============================] - 0s 7ms/step - loss: 0.0478 - binary_accuracy: 0.9855
# Epoch 17/50
# 53/53 [==============================] - 0s 7ms/step - loss: 0.0389 - binary_accuracy: 0.9879
# Epoch 18/50
# 53/53 [==============================] - 0s 7ms/step - loss: 0.0315 - binary_accuracy: 0.9906
# Epoch 19/50
# 53/53 [==============================] - 0s 7ms/step - loss: 0.0260 - binary_accuracy: 0.9922
# Epoch 20/50
# 53/53 [==============================] - 0s 8ms/step - loss: 0.0213 - binary_accuracy: 0.9934
# Epoch 21/50
# 53/53 [==============================] - 0s 9ms/step - loss: 0.0177 - binary_accuracy: 0.9946
# Epoch 22/50
# 53/53 [==============================] - 0s 7ms/step - loss: 0.0152 - binary_accuracy: 0.9949
# Epoch 23/50
# 53/53 [==============================] - 0s 7ms/step - loss: 0.0130 - binary_accuracy: 0.9956
# Epoch 24/50
# 53/53 [==============================] - 0s 7ms/step - loss: 0.0111 - binary_accuracy: 0.9963
# Epoch 25/50
# 53/53 [==============================] - 0s 7ms/step - loss: 0.0102 - binary_accuracy: 0.9966
# Epoch 26/50
# 53/53 [==============================] - 0s 7ms/step - loss: 0.0087 - binary_accuracy: 0.9969
# Epoch 27/50
# 53/53 [==============================] - 0s 7ms/step - loss: 0.0081 - binary_accuracy: 0.9968
# Epoch 28/50
# 53/53 [==============================] - 0s 7ms/step - loss: 0.0070 - binary_accuracy: 0.9969
# Epoch 29/50
# 53/53 [==============================] - 0s 7ms/step - loss: 0.0067 - binary_accuracy: 0.9974
# Epoch 30/50
# 53/53 [==============================] - 0s 7ms/step - loss: 0.0062 - binary_accuracy: 0.9976
# Epoch 31/50
# 53/53 [==============================] - 0s 7ms/step - loss: 0.0057 - binary_accuracy: 0.9974
# Epoch 32/50
# 53/53 [==============================] - 0s 7ms/step - loss: 0.0058 - binary_accuracy: 0.9976
# Epoch 33/50
# 53/53 [==============================] - 0s 7ms/step - loss: 0.0056 - binary_accuracy: 0.9977
# Epoch 34/50
# 53/53 [==============================] - 0s 7ms/step - loss: 0.0055 - binary_accuracy: 0.9976
# Epoch 35/50
# 53/53 [==============================] - 0s 7ms/step - loss: 0.0051 - binary_accuracy: 0.9979
# Epoch 36/50
# 53/53 [==============================] - 0s 7ms/step - loss: 0.0052 - binary_accuracy: 0.9977
# Epoch 37/50
# 53/53 [==============================] - 0s 7ms/step - loss: 0.0049 - binary_accuracy: 0.9978
# Epoch 38/50
# 53/53 [==============================] - 0s 7ms/step - loss: 0.0050 - binary_accuracy: 0.9978
# Epoch 39/50
# 53/53 [==============================] - 0s 7ms/step - loss: 0.0050 - binary_accuracy: 0.9979
# Epoch 40/50
# 53/53 [==============================] - 0s 7ms/step - loss: 0.0049 - binary_accuracy: 0.9980
# Epoch 41/50
# 53/53 [==============================] - 0s 8ms/step - loss: 0.0050 - binary_accuracy: 0.9980
# Epoch 42/50
# 53/53 [==============================] - 0s 7ms/step - loss: 0.0048 - binary_accuracy: 0.9979
# Epoch 43/50
# 53/53 [==============================] - 0s 7ms/step - loss: 0.0049 - binary_accuracy: 0.9977
# Epoch 44/50
# 53/53 [==============================] - 0s 7ms/step - loss: 0.0049 - binary_accuracy: 0.9977
# Epoch 45/50
# 53/53 [==============================] - 0s 7ms/step - loss: 0.0047 - binary_accuracy: 0.9978
# Epoch 46/50
# 53/53 [==============================] - 0s 7ms/step - loss: 0.0046 - binary_accuracy: 0.9978
# Epoch 47/50
# 53/53 [==============================] - 0s 7ms/step - loss: 0.0048 - binary_accuracy: 0.9977
# Epoch 48/50
# 53/53 [==============================] - 0s 8ms/step - loss: 0.0047 - binary_accuracy: 0.9977
# Epoch 49/50
# 53/53 [==============================] - 0s 7ms/step - loss: 0.0046 - binary_accuracy: 0.9980
# Epoch 50/50
# 53/53 [==============================] - 0s 7ms/step - loss: 0.0047 - binary_accuracy: 0.9979
# 362/362 [==============================] - 0s 1ms/step - loss: 2.2139 - binary_accuracy: 0.8140
# Epoch 1/50
# 53/53 [==============================] - 0s 7ms/step - loss: 0.4310 - binary_accuracy: 0.8500
# Epoch 2/50
# 53/53 [==============================] - 0s 7ms/step - loss: 0.3176 - binary_accuracy: 0.8629
# Epoch 3/50
# 53/53 [==============================] - 0s 7ms/step - loss: 0.2846 - binary_accuracy: 0.8774
# Epoch 4/50
# 53/53 [==============================] - 0s 7ms/step - loss: 0.2620 - binary_accuracy: 0.8890
# Epoch 5/50
# 53/53 [==============================] - 0s 7ms/step - loss: 0.2400 - binary_accuracy: 0.9010
# Epoch 6/50
# 53/53 [==============================] - 0s 7ms/step - loss: 0.2173 - binary_accuracy: 0.9122
# Epoch 7/50
# 53/53 [==============================] - 0s 7ms/step - loss: 0.1939 - binary_accuracy: 0.9243
# Epoch 8/50
# 53/53 [==============================] - 0s 7ms/step - loss: 0.1696 - binary_accuracy: 0.9356
# Epoch 9/50
# 53/53 [==============================] - 0s 7ms/step - loss: 0.1468 - binary_accuracy: 0.9452
# Epoch 10/50
# 53/53 [==============================] - 0s 7ms/step - loss: 0.1251 - binary_accuracy: 0.9564
# Epoch 11/50
# 53/53 [==============================] - 0s 8ms/step - loss: 0.1053 - binary_accuracy: 0.9642
# Epoch 12/50
# 53/53 [==============================] - 0s 7ms/step - loss: 0.0868 - binary_accuracy: 0.9720
# Epoch 13/50
# 53/53 [==============================] - 0s 7ms/step - loss: 0.0703 - binary_accuracy: 0.9782
# Epoch 14/50
# 53/53 [==============================] - 0s 7ms/step - loss: 0.0560 - binary_accuracy: 0.9833
# Epoch 15/50
# 53/53 [==============================] - 0s 7ms/step - loss: 0.0440 - binary_accuracy: 0.9874
# Epoch 16/50
# 53/53 [==============================] - 0s 8ms/step - loss: 0.0342 - binary_accuracy: 0.9908
# Epoch 17/50
# 53/53 [==============================] - 0s 7ms/step - loss: 0.0263 - binary_accuracy: 0.9932
# Epoch 18/50
# 53/53 [==============================] - 0s 8ms/step - loss: 0.0202 - binary_accuracy: 0.9946
# Epoch 19/50
# 53/53 [==============================] - 0s 8ms/step - loss: 0.0154 - binary_accuracy: 0.9961
# Epoch 20/50
# 53/53 [==============================] - 0s 8ms/step - loss: 0.0120 - binary_accuracy: 0.9968
# Epoch 21/50
# 53/53 [==============================] - 0s 8ms/step - loss: 0.0091 - binary_accuracy: 0.9974
# Epoch 22/50
# 53/53 [==============================] - 0s 7ms/step - loss: 0.0072 - binary_accuracy: 0.9981
# Epoch 23/50
# 53/53 [==============================] - 0s 8ms/step - loss: 0.0059 - binary_accuracy: 0.9984
# Epoch 24/50
# 53/53 [==============================] - 0s 7ms/step - loss: 0.0050 - binary_accuracy: 0.9988
# Epoch 25/50
# 53/53 [==============================] - 0s 8ms/step - loss: 0.0041 - binary_accuracy: 0.9988
# Epoch 26/50
# 53/53 [==============================] - 0s 8ms/step - loss: 0.0035 - binary_accuracy: 0.9990
# Epoch 27/50
# 53/53 [==============================] - 0s 8ms/step - loss: 0.0033 - binary_accuracy: 0.9989
# Epoch 28/50
# 53/53 [==============================] - 0s 8ms/step - loss: 0.0027 - binary_accuracy: 0.9989
# Epoch 29/50
# 53/53 [==============================] - 0s 7ms/step - loss: 0.0027 - binary_accuracy: 0.9989
# Epoch 30/50
# 53/53 [==============================] - 0s 8ms/step - loss: 0.0026 - binary_accuracy: 0.9990
# Epoch 31/50
# 53/53 [==============================] - 0s 8ms/step - loss: 0.0025 - binary_accuracy: 0.9990
# Epoch 32/50
# 53/53 [==============================] - 0s 7ms/step - loss: 0.0023 - binary_accuracy: 0.9990
# Epoch 33/50
# 53/53 [==============================] - 0s 7ms/step - loss: 0.0022 - binary_accuracy: 0.9991
# Epoch 34/50
# 53/53 [==============================] - 0s 7ms/step - loss: 0.0021 - binary_accuracy: 0.9993
# Epoch 35/50
# 53/53 [==============================] - 0s 7ms/step - loss: 0.0019 - binary_accuracy: 0.9992
# Epoch 36/50
# 53/53 [==============================] - 0s 7ms/step - loss: 0.0023 - binary_accuracy: 0.9992
# Epoch 37/50
# 53/53 [==============================] - 0s 7ms/step - loss: 0.0021 - binary_accuracy: 0.9991
# Epoch 38/50
# 53/53 [==============================] - 0s 7ms/step - loss: 0.0020 - binary_accuracy: 0.9991
# Epoch 39/50
# 53/53 [==============================] - 0s 7ms/step - loss: 0.0021 - binary_accuracy: 0.9991
# Epoch 40/50
# 53/53 [==============================] - 0s 7ms/step - loss: 0.0020 - binary_accuracy: 0.9991
# Epoch 41/50
# 53/53 [==============================] - 0s 7ms/step - loss: 0.0021 - binary_accuracy: 0.9991
# Epoch 42/50
# 53/53 [==============================] - 0s 7ms/step - loss: 0.0020 - binary_accuracy: 0.9991
# Epoch 43/50
# 53/53 [==============================] - 0s 8ms/step - loss: 0.0019 - binary_accuracy: 0.9993
# Epoch 44/50
# 53/53 [==============================] - 0s 7ms/step - loss: 0.0020 - binary_accuracy: 0.9991
# Epoch 45/50
# 53/53 [==============================] - 0s 7ms/step - loss: 0.0021 - binary_accuracy: 0.9991
# Epoch 46/50
# 53/53 [==============================] - 0s 7ms/step - loss: 0.0019 - binary_accuracy: 0.9992
# Epoch 47/50
# 53/53 [==============================] - 0s 7ms/step - loss: 0.0020 - binary_accuracy: 0.9992
# Epoch 48/50
# 53/53 [==============================] - 0s 7ms/step - loss: 0.0019 - binary_accuracy: 0.9991
# Epoch 49/50
# 53/53 [==============================] - 0s 7ms/step - loss: 0.0020 - binary_accuracy: 0.9992
# Epoch 50/50
# 53/53 [==============================] - 0s 7ms/step - loss: 0.0019 - binary_accuracy: 0.9991
# 362/362 [==============================] - 0s 1ms/step - loss: 2.5083 - binary_accuracy: 0.8218
# Epoch 1/50
# 53/53 [==============================] - 0s 8ms/step - loss: 0.4067 - binary_accuracy: 0.8589
# Epoch 2/50
# 53/53 [==============================] - 0s 7ms/step - loss: 0.2730 - binary_accuracy: 0.8904
# Epoch 3/50
# 53/53 [==============================] - 0s 7ms/step - loss: 0.2347 - binary_accuracy: 0.9083
# Epoch 4/50
# 53/53 [==============================] - 0s 7ms/step - loss: 0.2141 - binary_accuracy: 0.9160
# Epoch 5/50
# 53/53 [==============================] - 0s 7ms/step - loss: 0.1975 - binary_accuracy: 0.9234
# Epoch 6/50
# 53/53 [==============================] - 0s 7ms/step - loss: 0.1821 - binary_accuracy: 0.9295
# Epoch 7/50
# 53/53 [==============================] - 0s 7ms/step - loss: 0.1671 - binary_accuracy: 0.9360
# Epoch 8/50
# 53/53 [==============================] - 0s 7ms/step - loss: 0.1514 - binary_accuracy: 0.9439
# Epoch 9/50
# 53/53 [==============================] - 0s 7ms/step - loss: 0.1359 - binary_accuracy: 0.9511
# Epoch 10/50
# 53/53 [==============================] - 0s 7ms/step - loss: 0.1202 - binary_accuracy: 0.9569
# Epoch 11/50
# 53/53 [==============================] - 0s 7ms/step - loss: 0.1057 - binary_accuracy: 0.9630
# Epoch 12/50
# 53/53 [==============================] - 0s 7ms/step - loss: 0.0913 - binary_accuracy: 0.9696
# Epoch 13/50
# 53/53 [==============================] - 0s 7ms/step - loss: 0.0781 - binary_accuracy: 0.9746
# Epoch 14/50
# 53/53 [==============================] - 0s 7ms/step - loss: 0.0653 - binary_accuracy: 0.9782
# Epoch 15/50
# 53/53 [==============================] - 0s 7ms/step - loss: 0.0537 - binary_accuracy: 0.9824
# Epoch 16/50
# 53/53 [==============================] - 0s 7ms/step - loss: 0.0430 - binary_accuracy: 0.9872
# Epoch 17/50
# 53/53 [==============================] - 0s 7ms/step - loss: 0.0345 - binary_accuracy: 0.9894
# Epoch 18/50
# 53/53 [==============================] - 0s 7ms/step - loss: 0.0271 - binary_accuracy: 0.9922
# Epoch 19/50
# 53/53 [==============================] - 0s 7ms/step - loss: 0.0216 - binary_accuracy: 0.9937
# Epoch 20/50
# 53/53 [==============================] - 0s 7ms/step - loss: 0.0171 - binary_accuracy: 0.9953
# Epoch 21/50
# 53/53 [==============================] - 0s 7ms/step - loss: 0.0139 - binary_accuracy: 0.9959
# Epoch 22/50
# 53/53 [==============================] - 0s 7ms/step - loss: 0.0111 - binary_accuracy: 0.9970
# Epoch 23/50
# 53/53 [==============================] - 0s 7ms/step - loss: 0.0095 - binary_accuracy: 0.9971
# Epoch 24/50
# 53/53 [==============================] - 0s 7ms/step - loss: 0.0079 - binary_accuracy: 0.9979
# Epoch 25/50
# 53/53 [==============================] - 0s 7ms/step - loss: 0.0070 - binary_accuracy: 0.9981
# Epoch 26/50
# 53/53 [==============================] - 0s 7ms/step - loss: 0.0061 - binary_accuracy: 0.9980
# Epoch 27/50
# 53/53 [==============================] - 0s 7ms/step - loss: 0.0054 - binary_accuracy: 0.9983
# Epoch 28/50
# 53/53 [==============================] - 0s 7ms/step - loss: 0.0051 - binary_accuracy: 0.9983
# Epoch 29/50
# 53/53 [==============================] - 0s 7ms/step - loss: 0.0046 - binary_accuracy: 0.9986
# Epoch 30/50
# 53/53 [==============================] - 0s 7ms/step - loss: 0.0043 - binary_accuracy: 0.9984
# Epoch 31/50
# 53/53 [==============================] - 0s 7ms/step - loss: 0.0042 - binary_accuracy: 0.9986
# Epoch 32/50
# 53/53 [==============================] - 0s 7ms/step - loss: 0.0041 - binary_accuracy: 0.9985
# Epoch 33/50
# 53/53 [==============================] - 0s 7ms/step - loss: 0.0039 - binary_accuracy: 0.9985
# Epoch 34/50
# 53/53 [==============================] - 0s 8ms/step - loss: 0.0038 - binary_accuracy: 0.9985
# Epoch 35/50
# 53/53 [==============================] - 0s 7ms/step - loss: 0.0037 - binary_accuracy: 0.9987
# Epoch 36/50
# 53/53 [==============================] - 0s 8ms/step - loss: 0.0033 - binary_accuracy: 0.9987
# Epoch 37/50
# 53/53 [==============================] - 0s 7ms/step - loss: 0.0034 - binary_accuracy: 0.9988
# Epoch 38/50
# 53/53 [==============================] - 0s 7ms/step - loss: 0.0036 - binary_accuracy: 0.9987
# Epoch 39/50
# 53/53 [==============================] - 0s 7ms/step - loss: 0.0031 - binary_accuracy: 0.9987
# Epoch 40/50
# 53/53 [==============================] - 0s 7ms/step - loss: 0.0034 - binary_accuracy: 0.9985
# Epoch 41/50
# 53/53 [==============================] - 0s 7ms/step - loss: 0.0033 - binary_accuracy: 0.9987
# Epoch 42/50
# 53/53 [==============================] - 0s 7ms/step - loss: 0.0033 - binary_accuracy: 0.9987
# Epoch 43/50
# 53/53 [==============================] - 0s 7ms/step - loss: 0.0031 - binary_accuracy: 0.9986
# Epoch 44/50
# 53/53 [==============================] - 0s 8ms/step - loss: 0.0032 - binary_accuracy: 0.9986
# Epoch 45/50
# 53/53 [==============================] - 0s 7ms/step - loss: 0.0031 - binary_accuracy: 0.9987
# Epoch 46/50
# 53/53 [==============================] - 0s 7ms/step - loss: 0.0030 - binary_accuracy: 0.9989
# Epoch 47/50
# 53/53 [==============================] - 0s 7ms/step - loss: 0.0033 - binary_accuracy: 0.9987
# Epoch 48/50
# 53/53 [==============================] - 0s 7ms/step - loss: 0.0032 - binary_accuracy: 0.9986
# Epoch 49/50
# 53/53 [==============================] - 0s 7ms/step - loss: 0.0032 - binary_accuracy: 0.9985
# Epoch 50/50
# 53/53 [==============================] - 0s 7ms/step - loss: 0.0031 - binary_accuracy: 0.9986
# 362/362 [==============================] - 0s 1ms/step - loss: 1.6709 - binary_accuracy: 0.8618
# Epoch 1/50
# 53/53 [==============================] - 0s 8ms/step - loss: 0.4145 - binary_accuracy: 0.8689
# Epoch 2/50
# 53/53 [==============================] - 0s 8ms/step - loss: 0.3272 - binary_accuracy: 0.8748
# Epoch 3/50
# 53/53 [==============================] - 0s 8ms/step - loss: 0.2982 - binary_accuracy: 0.8785
# Epoch 4/50
# 53/53 [==============================] - 0s 8ms/step - loss: 0.2767 - binary_accuracy: 0.8871
# Epoch 5/50
# 53/53 [==============================] - 0s 7ms/step - loss: 0.2566 - binary_accuracy: 0.8974
# Epoch 6/50
# 53/53 [==============================] - 0s 8ms/step - loss: 0.2346 - binary_accuracy: 0.9090
# Epoch 7/50
# 53/53 [==============================] - 0s 7ms/step - loss: 0.2112 - binary_accuracy: 0.9201
# Epoch 8/50
# 53/53 [==============================] - 0s 8ms/step - loss: 0.1883 - binary_accuracy: 0.9283
# Epoch 9/50
# 53/53 [==============================] - 0s 7ms/step - loss: 0.1652 - binary_accuracy: 0.9382
# Epoch 10/50
# 53/53 [==============================] - 0s 7ms/step - loss: 0.1437 - binary_accuracy: 0.9477
# Epoch 11/50
# 53/53 [==============================] - 0s 7ms/step - loss: 0.1232 - binary_accuracy: 0.9571
# Epoch 12/50
# 53/53 [==============================] - 0s 8ms/step - loss: 0.1034 - binary_accuracy: 0.9639
# Epoch 13/50
# 53/53 [==============================] - 0s 8ms/step - loss: 0.0852 - binary_accuracy: 0.9716
# Epoch 14/50
# 53/53 [==============================] - 0s 8ms/step - loss: 0.0684 - binary_accuracy: 0.9779
# Epoch 15/50
# 53/53 [==============================] - 0s 7ms/step - loss: 0.0543 - binary_accuracy: 0.9830
# Epoch 16/50
# 53/53 [==============================] - 0s 7ms/step - loss: 0.0430 - binary_accuracy: 0.9881
# Epoch 17/50
# 53/53 [==============================] - 0s 8ms/step - loss: 0.0336 - binary_accuracy: 0.9907
# Epoch 18/50
# 53/53 [==============================] - 0s 8ms/step - loss: 0.0264 - binary_accuracy: 0.9923
# Epoch 19/50
# 53/53 [==============================] - 0s 7ms/step - loss: 0.0215 - binary_accuracy: 0.9942
# Epoch 20/50
# 53/53 [==============================] - 0s 8ms/step - loss: 0.0168 - binary_accuracy: 0.9956
# Epoch 21/50
# 53/53 [==============================] - 0s 7ms/step - loss: 0.0138 - binary_accuracy: 0.9961
# Epoch 22/50
# 53/53 [==============================] - 0s 8ms/step - loss: 0.0110 - binary_accuracy: 0.9967
# Epoch 23/50
# 53/53 [==============================] - 0s 7ms/step - loss: 0.0092 - binary_accuracy: 0.9974
# Epoch 24/50
# 53/53 [==============================] - 0s 7ms/step - loss: 0.0082 - binary_accuracy: 0.9974
# Epoch 25/50
# 53/53 [==============================] - 0s 8ms/step - loss: 0.0072 - binary_accuracy: 0.9978
# Epoch 26/50
# 53/53 [==============================] - 0s 7ms/step - loss: 0.0063 - binary_accuracy: 0.9981
# Epoch 27/50
# 53/53 [==============================] - 0s 8ms/step - loss: 0.0055 - binary_accuracy: 0.9982
# Epoch 28/50
# 53/53 [==============================] - 0s 7ms/step - loss: 0.0050 - binary_accuracy: 0.9983
# Epoch 29/50
# 53/53 [==============================] - 0s 7ms/step - loss: 0.0047 - binary_accuracy: 0.9983
# Epoch 30/50
# 53/53 [==============================] - 0s 7ms/step - loss: 0.0045 - binary_accuracy: 0.9987
# Epoch 31/50
# 53/53 [==============================] - 0s 7ms/step - loss: 0.0042 - binary_accuracy: 0.9985
# Epoch 32/50
# 53/53 [==============================] - 0s 8ms/step - loss: 0.0038 - binary_accuracy: 0.9989
# Epoch 33/50
# 53/53 [==============================] - 0s 8ms/step - loss: 0.0038 - binary_accuracy: 0.9986
# Epoch 34/50
# 53/53 [==============================] - 0s 7ms/step - loss: 0.0036 - binary_accuracy: 0.9988
# Epoch 35/50
# 53/53 [==============================] - 0s 7ms/step - loss: 0.0035 - binary_accuracy: 0.9988
# Epoch 36/50
# 53/53 [==============================] - 0s 7ms/step - loss: 0.0033 - binary_accuracy: 0.9987
# Epoch 37/50
# 53/53 [==============================] - 0s 8ms/step - loss: 0.0033 - binary_accuracy: 0.9989
# Epoch 38/50
# 53/53 [==============================] - 0s 8ms/step - loss: 0.0033 - binary_accuracy: 0.9987
# Epoch 39/50
# 53/53 [==============================] - 0s 8ms/step - loss: 0.0032 - binary_accuracy: 0.9987
# Epoch 40/50
# 53/53 [==============================] - 0s 7ms/step - loss: 0.0031 - binary_accuracy: 0.9988
# Epoch 41/50
# 53/53 [==============================] - 0s 7ms/step - loss: 0.0028 - binary_accuracy: 0.9989
# Epoch 42/50
# 53/53 [==============================] - 0s 7ms/step - loss: 0.0030 - binary_accuracy: 0.9990
# Epoch 43/50
# 53/53 [==============================] - 0s 7ms/step - loss: 0.0033 - binary_accuracy: 0.9989
# Epoch 44/50
# 53/53 [==============================] - 0s 7ms/step - loss: 0.0029 - binary_accuracy: 0.9988
# Epoch 45/50
# 53/53 [==============================] - 0s 8ms/step - loss: 0.0031 - binary_accuracy: 0.9988
# Epoch 46/50
# 53/53 [==============================] - 0s 7ms/step - loss: 0.0030 - binary_accuracy: 0.9988
# Epoch 47/50
# 53/53 [==============================] - 0s 7ms/step - loss: 0.0030 - binary_accuracy: 0.9989
# Epoch 48/50
# 53/53 [==============================] - 0s 7ms/step - loss: 0.0029 - binary_accuracy: 0.9989
# Epoch 49/50
# 53/53 [==============================] - 0s 7ms/step - loss: 0.0027 - binary_accuracy: 0.9987
# Epoch 50/50
# 53/53 [==============================] - 0s 7ms/step - loss: 0.0026 - binary_accuracy: 0.9989
# 362/362 [==============================] - 0s 1ms/step - loss: 2.2310 - binary_accuracy: 0.8268
# Epoch 1/50
# 53/53 [==============================] - 0s 7ms/step - loss: 0.3724 - binary_accuracy: 0.8605
# Epoch 2/50
# 53/53 [==============================] - 0s 8ms/step - loss: 0.2085 - binary_accuracy: 0.9278
# Epoch 3/50
# 53/53 [==============================] - 0s 6ms/step - loss: 0.1700 - binary_accuracy: 0.9387
# Epoch 4/50
# 53/53 [==============================] - 0s 6ms/step - loss: 0.1526 - binary_accuracy: 0.9435
# Epoch 5/50
# 53/53 [==============================] - 0s 7ms/step - loss: 0.1398 - binary_accuracy: 0.9479
# Epoch 6/50
# 53/53 [==============================] - 0s 7ms/step - loss: 0.1297 - binary_accuracy: 0.9521
# Epoch 7/50
# 53/53 [==============================] - 0s 7ms/step - loss: 0.1196 - binary_accuracy: 0.9558
# Epoch 8/50
# 53/53 [==============================] - 0s 7ms/step - loss: 0.1105 - binary_accuracy: 0.9593
# Epoch 9/50
# 53/53 [==============================] - 0s 7ms/step - loss: 0.1008 - binary_accuracy: 0.9631
# Epoch 10/50
# 53/53 [==============================] - 0s 7ms/step - loss: 0.0922 - binary_accuracy: 0.9672
# Epoch 11/50
# 53/53 [==============================] - 0s 8ms/step - loss: 0.0829 - binary_accuracy: 0.9708
# Epoch 12/50
# 53/53 [==============================] - 0s 8ms/step - loss: 0.0744 - binary_accuracy: 0.9741
# Epoch 13/50
# 53/53 [==============================] - 0s 7ms/step - loss: 0.0666 - binary_accuracy: 0.9767
# Epoch 14/50
# 53/53 [==============================] - 0s 8ms/step - loss: 0.0587 - binary_accuracy: 0.9797
# Epoch 15/50
# 53/53 [==============================] - 0s 8ms/step - loss: 0.0510 - binary_accuracy: 0.9826
# Epoch 16/50
# 53/53 [==============================] - 0s 7ms/step - loss: 0.0443 - binary_accuracy: 0.9855
# Epoch 17/50
# 53/53 [==============================] - 0s 9ms/step - loss: 0.0379 - binary_accuracy: 0.9880
# Epoch 18/50
# 53/53 [==============================] - 0s 8ms/step - loss: 0.0320 - binary_accuracy: 0.9898
# Epoch 19/50
# 53/53 [==============================] - 0s 9ms/step - loss: 0.0269 - binary_accuracy: 0.9915
# Epoch 20/50
# 53/53 [==============================] - 0s 9ms/step - loss: 0.0228 - binary_accuracy: 0.9930
# Epoch 21/50
# 53/53 [==============================] - 0s 7ms/step - loss: 0.0191 - binary_accuracy: 0.9943
# Epoch 22/50
# 53/53 [==============================] - 0s 8ms/step - loss: 0.0164 - binary_accuracy: 0.9949
# Epoch 23/50
# 53/53 [==============================] - 0s 7ms/step - loss: 0.0141 - binary_accuracy: 0.9956
# Epoch 24/50
# 53/53 [==============================] - 0s 9ms/step - loss: 0.0119 - binary_accuracy: 0.9962
# Epoch 25/50
# 53/53 [==============================] - 1s 10ms/step - loss: 0.0105 - binary_accuracy: 0.9967
# Epoch 26/50
# 53/53 [==============================] - 0s 9ms/step - loss: 0.0091 - binary_accuracy: 0.9971
# Epoch 27/50
# 53/53 [==============================] - 0s 8ms/step - loss: 0.0084 - binary_accuracy: 0.9970
# Epoch 28/50
# 53/53 [==============================] - 0s 7ms/step - loss: 0.0072 - binary_accuracy: 0.9973
# Epoch 29/50
# 53/53 [==============================] - 0s 8ms/step - loss: 0.0066 - binary_accuracy: 0.9976
# Epoch 30/50
# 53/53 [==============================] - 0s 7ms/step - loss: 0.0057 - binary_accuracy: 0.9979
# Epoch 31/50
# 53/53 [==============================] - 0s 8ms/step - loss: 0.0054 - binary_accuracy: 0.9980
# Epoch 32/50
# 53/53 [==============================] - 0s 8ms/step - loss: 0.0050 - binary_accuracy: 0.9982
# Epoch 33/50
# 53/53 [==============================] - 0s 9ms/step - loss: 0.0046 - binary_accuracy: 0.9982
# Epoch 34/50
# 53/53 [==============================] - 1s 10ms/step - loss: 0.0045 - binary_accuracy: 0.9984
# Epoch 35/50
# 53/53 [==============================] - 0s 9ms/step - loss: 0.0042 - binary_accuracy: 0.9984
# Epoch 36/50
# 53/53 [==============================] - 0s 7ms/step - loss: 0.0039 - binary_accuracy: 0.9986
# Epoch 37/50
# 53/53 [==============================] - 0s 8ms/step - loss: 0.0036 - binary_accuracy: 0.9986
# Epoch 38/50
# 53/53 [==============================] - 0s 9ms/step - loss: 0.0035 - binary_accuracy: 0.9985
# Epoch 39/50
# 53/53 [==============================] - 0s 8ms/step - loss: 0.0035 - binary_accuracy: 0.9986
# Epoch 40/50
# 53/53 [==============================] - 0s 8ms/step - loss: 0.0032 - binary_accuracy: 0.9988
# Epoch 41/50
# 53/53 [==============================] - 0s 8ms/step - loss: 0.0032 - binary_accuracy: 0.9987
# Epoch 42/50
# 53/53 [==============================] - 0s 8ms/step - loss: 0.0032 - binary_accuracy: 0.9987
# Epoch 43/50
# 53/53 [==============================] - 0s 7ms/step - loss: 0.0030 - binary_accuracy: 0.9987
# Epoch 44/50
# 53/53 [==============================] - 0s 9ms/step - loss: 0.0031 - binary_accuracy: 0.9987
# Epoch 45/50
# 53/53 [==============================] - 1s 11ms/step - loss: 0.0029 - binary_accuracy: 0.9987
# Epoch 46/50
# 53/53 [==============================] - 0s 8ms/step - loss: 0.0029 - binary_accuracy: 0.9986
# Epoch 47/50
# 53/53 [==============================] - 0s 7ms/step - loss: 0.0029 - binary_accuracy: 0.9986
# Epoch 48/50
# 53/53 [==============================] - 0s 7ms/step - loss: 0.0029 - binary_accuracy: 0.9987
# Epoch 49/50
# 53/53 [==============================] - 0s 9ms/step - loss: 0.0027 - binary_accuracy: 0.9986
# Epoch 50/50
# 53/53 [==============================] - 1s 10ms/step - loss: 0.0028 - binary_accuracy: 0.9987
# 362/362 [==============================] - 1s 1ms/step - loss: 1.6721 - binary_accuracy: 0.8852
# Epoch 1/50
# 53/53 [==============================] - 0s 8ms/step - loss: 0.4492 - binary_accuracy: 0.8542
# Epoch 2/50
# 53/53 [==============================] - 0s 7ms/step - loss: 0.3478 - binary_accuracy: 0.8596
# Epoch 3/50
# 53/53 [==============================] - 0s 7ms/step - loss: 0.3160 - binary_accuracy: 0.8658
# Epoch 4/50
# 53/53 [==============================] - 0s 7ms/step - loss: 0.2926 - binary_accuracy: 0.8776
# Epoch 5/50
# 53/53 [==============================] - 0s 6ms/step - loss: 0.2691 - binary_accuracy: 0.8915
# Epoch 6/50
# 53/53 [==============================] - 0s 7ms/step - loss: 0.2448 - binary_accuracy: 0.9049
# Epoch 7/50
# 53/53 [==============================] - 0s 6ms/step - loss: 0.2191 - binary_accuracy: 0.9168
# Epoch 8/50
# 53/53 [==============================] - 0s 7ms/step - loss: 0.1926 - binary_accuracy: 0.9303
# Epoch 9/50
# 53/53 [==============================] - 0s 7ms/step - loss: 0.1678 - binary_accuracy: 0.9397
# Epoch 10/50
# 53/53 [==============================] - 0s 7ms/step - loss: 0.1421 - binary_accuracy: 0.9507
# Epoch 11/50
# 53/53 [==============================] - 0s 7ms/step - loss: 0.1184 - binary_accuracy: 0.9610
# Epoch 12/50
# 53/53 [==============================] - 0s 7ms/step - loss: 0.0959 - binary_accuracy: 0.9700
# Epoch 13/50
# 53/53 [==============================] - 0s 6ms/step - loss: 0.0754 - binary_accuracy: 0.9774
# Epoch 14/50
# 53/53 [==============================] - 0s 7ms/step - loss: 0.0590 - binary_accuracy: 0.9835
# Epoch 15/50
# 53/53 [==============================] - 0s 7ms/step - loss: 0.0454 - binary_accuracy: 0.9884
# Epoch 16/50
# 53/53 [==============================] - 0s 7ms/step - loss: 0.0327 - binary_accuracy: 0.9913
# Epoch 17/50
# 53/53 [==============================] - 0s 7ms/step - loss: 0.0250 - binary_accuracy: 0.9939
# Epoch 18/50
# 53/53 [==============================] - 0s 6ms/step - loss: 0.0178 - binary_accuracy: 0.9958
# Epoch 19/50
# 53/53 [==============================] - 0s 7ms/step - loss: 0.0143 - binary_accuracy: 0.9970
# Epoch 20/50
# 53/53 [==============================] - 0s 7ms/step - loss: 0.0096 - binary_accuracy: 0.9979
# Epoch 21/50
# 53/53 [==============================] - 0s 6ms/step - loss: 0.0073 - binary_accuracy: 0.9984
# Epoch 22/50
# 53/53 [==============================] - 0s 7ms/step - loss: 0.0071 - binary_accuracy: 0.9986
# Epoch 23/50
# 53/53 [==============================] - 0s 7ms/step - loss: 0.0047 - binary_accuracy: 0.9989
# Epoch 24/50
# 53/53 [==============================] - 0s 7ms/step - loss: 0.0039 - binary_accuracy: 0.9990
# Epoch 25/50
# 53/53 [==============================] - 0s 7ms/step - loss: 0.0032 - binary_accuracy: 0.9990
# Epoch 26/50
# 53/53 [==============================] - 0s 7ms/step - loss: 0.0040 - binary_accuracy: 0.9992
# Epoch 27/50
# 53/53 [==============================] - 0s 6ms/step - loss: 0.0026 - binary_accuracy: 0.9992
# Epoch 28/50
# 53/53 [==============================] - 0s 7ms/step - loss: 0.0025 - binary_accuracy: 0.9993
# Epoch 29/50
# 53/53 [==============================] - 0s 6ms/step - loss: 0.0023 - binary_accuracy: 0.9992
# Epoch 30/50
# 53/53 [==============================] - 0s 7ms/step - loss: 0.0023 - binary_accuracy: 0.9990
# Epoch 31/50
# 53/53 [==============================] - 0s 7ms/step - loss: 0.0021 - binary_accuracy: 0.9993
# Epoch 32/50
# 53/53 [==============================] - 0s 6ms/step - loss: 0.0023 - binary_accuracy: 0.9991
# Epoch 33/50
# 53/53 [==============================] - 0s 7ms/step - loss: 0.0020 - binary_accuracy: 0.9993
# Epoch 34/50
# 53/53 [==============================] - 0s 7ms/step - loss: 0.0022 - binary_accuracy: 0.9992
# Epoch 35/50
# 53/53 [==============================] - 0s 6ms/step - loss: 0.0020 - binary_accuracy: 0.9992
# Epoch 36/50
# 53/53 [==============================] - 0s 7ms/step - loss: 0.0020 - binary_accuracy: 0.9992
# Epoch 37/50
# 53/53 [==============================] - 0s 7ms/step - loss: 0.0019 - binary_accuracy: 0.9993
# Epoch 38/50
# 53/53 [==============================] - 0s 6ms/step - loss: 0.0019 - binary_accuracy: 0.9993
# Epoch 39/50
# 53/53 [==============================] - 0s 7ms/step - loss: 0.0046 - binary_accuracy: 0.9993
# Epoch 40/50
# 53/53 [==============================] - 0s 6ms/step - loss: 0.0019 - binary_accuracy: 0.9992
# Epoch 41/50
# 53/53 [==============================] - 0s 7ms/step - loss: 0.0018 - binary_accuracy: 0.9993
# Epoch 42/50
# 53/53 [==============================] - 0s 7ms/step - loss: 0.0019 - binary_accuracy: 0.9992
# Epoch 43/50
# 53/53 [==============================] - 0s 6ms/step - loss: 0.0018 - binary_accuracy: 0.9993
# Epoch 44/50
# 53/53 [==============================] - 0s 7ms/step - loss: 0.0018 - binary_accuracy: 0.9993
# Epoch 45/50
# 53/53 [==============================] - 0s 7ms/step - loss: 0.0019 - binary_accuracy: 0.9992
# Epoch 46/50
# 53/53 [==============================] - 0s 6ms/step - loss: 0.0019 - binary_accuracy: 0.9993
# Epoch 47/50
# 53/53 [==============================] - 0s 7ms/step - loss: 0.0019 - binary_accuracy: 0.9993
# Epoch 48/50
# 53/53 [==============================] - 0s 7ms/step - loss: 0.0019 - binary_accuracy: 0.9993
# Epoch 49/50
# 53/53 [==============================] - 0s 7ms/step - loss: 0.0019 - binary_accuracy: 0.9993
# Epoch 50/50
# 53/53 [==============================] - 0s 7ms/step - loss: 0.0018 - binary_accuracy: 0.9993
# 362/362 [==============================] - 0s 1ms/step - loss: 3.9568 - binary_accuracy: 0.7826

# %%
predict("내가 키우던 강아지가 오늘 죽었어")
# Out:
# ---------------------------------------------------------------------------
# ZeroDivisionError                         Traceback (most recent call last)
# <ipython-input-16-dbd2b31b2139> in <module>
# ----> 1 predict("내가 키우던 강아지가 오늘 죽었어")
#
# <ipython-input-1-bfda8bb16e22> in predict(predict)
#     543     df = pd.DataFrame({
#     544     'Character': ['RESULT'],
# --> 545     'Fear': [round(100/(total)*fear)],
#     546     'Disgust': [round(100/(total)*disgust)],
#     547     'Sadness': [round(100/(total)*sadness)],
#
# ZeroDivisionError: division by zero
