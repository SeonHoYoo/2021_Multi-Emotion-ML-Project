# %%
#fear emotion

#데이터 pandas로 읽기, 구문이 탭으로 구분되어있음.
import pandas as pd
train_fear_df = pd.read_csv("feartrainalldata.txt","\t") 
test_fear_df = pd.read_csv("feartestalldata.txt","\t")

#konlpy는 띄어쓰기 알고리즘과 정규화를 이용해 맞춤법이 틀린 문장을 고치고 형태소 분석과 품사를 태깅해주는 클래스를 제공함.
from konlpy.tag import Okt
okt_fear = Okt()

def fear_tokenize(doc):
    return ['/'.join(t) for t in okt_fear.pos(doc, norm=True, stem=True)] 
    #'구분자'.join(list) => 리스트 값과 값 사이에 구분자를 넣어 문자열을 하나로 합침. ex) '_'.join(['a','b','c'])이면 "a_b_c"로 반환
    #pos(text) => 품사를 태깅한 상태로 명사를 변환, ex) 컴퓨터(x), 컵퓨터,noun(o)
    #norm => 정규화 ex) 그래욬ㅋㅋㅋ => 그래요
    #stem => 근어로 표현 ex) 그래요 => 그렇다

train_fear_df.isnull().any()
train_fear_df['document'] = train_fear_df['document'].fillna(''); #null값을 ''로 대체
test_fear_df.isnull().any()
test_fear_df['document'] = test_fear_df['document'].fillna('');

train_fear_docs = [(fear_tokenize(row[1]), row[2]) for row in train_fear_df.values] #traindata 저장 row[1] : document / row[2] : label
test_fear_docs = [(fear_tokenize(row[1]),row[2]) for row in test_fear_df.values] #testdata 저장

tokens = [t for d in train_fear_docs for t in d[0]]

import nltk
fear_text = nltk.Text(tokens, name='FEAR') 
#문서 하나를 편리하게 탐색할 수 있는 기능 제공 (vocab().most_common() 사용)
# print(len(fear_text.tokens)) #토큰 개수
# print(len(set(fear_text.tokens))) #중복을 제외한 토큰 수
# print(fear_text.vocab().most_common(10)) #출력빈도가 높은 상위 토큰 10개

#countvectorization
FEAR_FREQUENCY_COUNT = 2000; #자주 사용되는 토큰 설정
fear_selected_words = [f[0] for f in fear_text.vocab().most_common(FEAR_FREQUENCY_COUNT)] #선택되어진 토큰들

def fear_term_frequency(doc):
    return [doc.count(word) for word in fear_selected_words]

x_fear_train = [fear_term_frequency(d) for d,_ in train_fear_docs]
x_fear_test = [fear_term_frequency(d) for d,_ in test_fear_docs]
#x축에는 문서에 들어가는 단어 개수(단어들의 빈도수 정보)

y_fear_train = [c for _,c in train_fear_docs]
y_fear_test = [c for _,c in test_fear_docs]
#y축에는 1 or 0, 분류 결과

import numpy as np
x_fear_train = np.asarray(x_fear_train).astype('float32')
x_fear_test = np.asarray(x_fear_test). astype('float32')

y_fear_train = np.asarray(y_fear_train).astype('float32')
y_fear_test = np.asarray(y_fear_test).astype('float32')
#np.asarray는 np.array와 달리 데이터 형태가 같을 때 복사하지 않음.
#데이터 float로 형 변환

import tensorflow as tf #텐서플로 케라스
fear_model= tf.keras.models.Sequential([
    tf.keras.layers.Dense(64, activation = 'relu',input_shape=(FEAR_FREQUENCY_COUNT,)),
    tf.keras.layers.Dense(64, activation = 'relu'),
    tf.keras.layers.Dense(1, activation = 'sigmoid')
])
#레이어 구성은 dense층은 64개의 유닛, 활성함수는 relu, 마지막 층은 sigmoid 활성화 함수 사용

fear_model.compile(optimizer=tf.keras.optimizers.RMSprop(lr=0.001),
             loss=tf.keras.losses.binary_crossentropy,
             metrics=[tf.keras.metrics.binary_accuracy]
             )
#손실 함수는 binary_crossentropy, RMSprop 옵티마이저를 통해 경사하강법 진행

fear_model.fit(x_fear_train, y_fear_train, epochs=50, batch_size=512)
#배치 사이즈 줄이면 한 번에 판단하는 데이터 수 증가함. 에포크 50번
fear_results = fear_model.evaluate(x_fear_test, y_fear_test)

fear_review = "너무 무섭다"
fear_token = fear_tokenize(fear_review)

fear_tf = fear_term_frequency(fear_token)
f_data = np.expand_dims(np.asarray(fear_tf).astype('float32'),axis=0)
float(fear_model.predict(f_data))

#surprise emotion

import pandas as pd
train_surprise_df = pd.read_csv("surprisetrainalldata.txt","\t")
test_surprise_df = pd.read_csv("surprisetestalldata.txt","\t")

from konlpy.tag import Okt
okt_surprise = Okt()

def surprise_tokenize(doc):
    return ['/'.join(t) for t in okt_surprise.pos(doc, norm=True, stem=True)]

train_surprise_df.isnull().any()
train_surprise_df['document'] = train_surprise_df['document'].fillna('');
test_surprise_df.isnull().any()
test_surprise_df['document'] = test_surprise_df['document'].fillna('');

train_surprise_docs = [(surprise_tokenize(row[1]), row[2]) for row in train_surprise_df.values]
test_surprise_docs = [(surprise_tokenize(row[1]),row[2]) for row in test_surprise_df.values]

tokens = [t for d in train_surprise_docs for t in d[0]]

import nltk
surprise_text = nltk.Text(tokens, name='SURP')
#print(len(surprise_text.tokens))
#print(len(set(surprise_text.tokens)))
#print(surprise_text.vocab().most_common(10))

SURPRISE_FREQUENCY_COUNT = 2000; #variable
surprise_selected_words = [f[0] for f in surprise_text.vocab().most_common(SURPRISE_FREQUENCY_COUNT)]

def surprise_term_frequency(doc):
    return [doc.count(word) for word in surprise_selected_words]

x_surprise_train = [surprise_term_frequency(d) for d,_ in train_surprise_docs]
x_surprise_test = [surprise_term_frequency(d) for d,_ in test_surprise_docs]
y_surprise_train = [c for _,c in train_surprise_docs]
y_surprise_test = [c for _,c in test_surprise_docs]

import numpy as np
x_surprise_train = np.asarray(x_surprise_train).astype('float32')
x_surprise_test = np.asarray(x_surprise_test). astype('float32')

y_surprise_train = np.asarray(y_surprise_train).astype('float32')
y_surprise_test = np.asarray(y_surprise_test).astype('float32')

import tensorflow as tf
surprise_model= tf.keras.models.Sequential([
    tf.keras.layers.Dense(64, activation = 'relu',input_shape=(SURPRISE_FREQUENCY_COUNT,)),
    tf.keras.layers.Dense(64, activation = 'relu'),
    tf.keras.layers.Dense(1, activation = 'sigmoid')
])

surprise_model.compile(optimizer=tf.keras.optimizers.RMSprop(lr=0.001),
             loss=tf.keras.losses.binary_crossentropy,
             metrics=[tf.keras.metrics.binary_accuracy]
             )

surprise_model.fit(x_surprise_train, y_surprise_train, epochs=50, batch_size=512)
surprise_results = surprise_model.evaluate(x_surprise_test, y_surprise_test)
surprise_review = "너무 놀랍다"
surprise_token = surprise_tokenize(surprise_review)

tf = surprise_term_frequency(surprise_token)
data = np.expand_dims(np.asarray(tf).astype('float32'),axis=0)
float(surprise_model.predict(data))

#anger emotion

import pandas as pd
train_anger_df = pd.read_csv("angertrainalldata.txt","\t")
test_anger_df = pd.read_csv("angertestalldata.txt","\t")

from konlpy.tag import Okt
okt_anger = Okt()

def anger_tokenize(doc):
    return ['/'.join(t) for t in okt_anger.pos(doc, norm=True, stem=True)]

train_anger_df.isnull().any()
train_anger_df['document'] = train_anger_df['document'].fillna('');
test_anger_df.isnull().any()
test_anger_df['document'] = test_anger_df['document'].fillna('');

train_anger_docs = [(anger_tokenize(row[1]), row[2]) for row in train_anger_df.values]
test_anger_docs = [(anger_tokenize(row[1]),row[2]) for row in test_anger_df.values]

tokens = [t for d in train_anger_docs for t in d[0]]

import nltk
anger_text = nltk.Text(tokens, name='ANGE')
#print(len(anger_text.tokens))
#print(len(set(anger_text.tokens)))
#print(anger_text.vocab().most_common(10))

ANGER_FREQUENCY_COUNT = 2000; #variable
anger_selected_words = [f[0] for f in anger_text.vocab().most_common(ANGER_FREQUENCY_COUNT)]

def anger_term_frequency(doc):
    return [doc.count(word) for word in anger_selected_words]

x_anger_train = [anger_term_frequency(d) for d,_ in train_anger_docs]
x_anger_test = [anger_term_frequency(d) for d,_ in test_anger_docs]
y_anger_train = [c for _,c in train_anger_docs]
y_anger_test = [c for _,c in test_anger_docs]

import numpy as np
x_anger_train = np.asarray(x_anger_train).astype('float32')
x_anger_test = np.asarray(x_anger_test). astype('float32')

y_anger_train = np.asarray(y_anger_train).astype('float32')
y_anger_test = np.asarray(y_anger_test).astype('float32')

import tensorflow as tf
anger_model= tf.keras.models.Sequential([
    tf.keras.layers.Dense(64, activation = 'relu',input_shape=(ANGER_FREQUENCY_COUNT,)),
    tf.keras.layers.Dense(64, activation = 'relu'),
    tf.keras.layers.Dense(1, activation = 'sigmoid')
])

anger_model.compile(optimizer=tf.keras.optimizers.RMSprop(lr=0.001),
             loss=tf.keras.losses.binary_crossentropy,
             metrics=[tf.keras.metrics.binary_accuracy]
             )

anger_model.fit(x_anger_train, y_anger_train, epochs=50, batch_size=512)
anger_results = anger_model.evaluate(x_anger_test, y_anger_test)

anger_review = "너무 화난다"
anger_token = anger_tokenize(anger_review)

tf = anger_term_frequency(anger_token)
data = np.expand_dims(np.asarray(tf).astype('float32'),axis=0)
float(anger_model.predict(data))

#sadness emotion

import pandas as pd
train_sadness_df = pd.read_csv("sadnesstrainalldata.txt","\t")
test_sadness_df = pd.read_csv("sadnesstestalldata.txt","\t")

from konlpy.tag import Okt
okt_sadness = Okt()

def sadness_tokenize(doc):
    return ['/'.join(t) for t in okt_sadness.pos(doc, norm=True, stem=True)]

train_sadness_df.isnull().any()
train_sadness_df['document'] = train_sadness_df['document'].fillna('');
test_sadness_df.isnull().any()
test_sadness_df['document'] = test_sadness_df['document'].fillna('');

train_sadness_docs = [(sadness_tokenize(row[1]), row[2]) for row in train_sadness_df.values]
test_sadness_docs = [(sadness_tokenize(row[1]),row[2]) for row in test_sadness_df.values]

tokens = [t for d in train_sadness_docs for t in d[0]]

import nltk
sadness_text = nltk.Text(tokens, name='SADN')
#print(len(sadness_text.tokens))
#print(len(set(sadness_text.tokens)))
#print(sadness_text.vocab().most_common(10))

SADNESS_FREQUENCY_COUNT = 2000; #variable
sadness_selected_words = [f[0] for f in fear_text.vocab().most_common(SADNESS_FREQUENCY_COUNT)]

def sadness_term_frequency(doc):
    return [doc.count(word) for word in sadness_selected_words]

x_sadness_train = [sadness_term_frequency(d) for d,_ in train_sadness_docs]
x_sadness_test = [sadness_term_frequency(d) for d,_ in test_sadness_docs]
y_sadness_train = [c for _,c in train_sadness_docs]
y_sadness_test = [c for _,c in test_sadness_docs]

import numpy as np
x_sadness_train = np.asarray(x_sadness_train).astype('float32')
x_sadness_test = np.asarray(x_sadness_test). astype('float32')

y_sadness_train = np.asarray(y_sadness_train).astype('float32')
y_sadness_test = np.asarray(y_sadness_test).astype('float32')

import tensorflow as tf
sadness_model= tf.keras.models.Sequential([
    tf.keras.layers.Dense(64, activation = 'relu',input_shape=(SADNESS_FREQUENCY_COUNT,)),
    tf.keras.layers.Dense(64, activation = 'relu'),
    tf.keras.layers.Dense(1, activation = 'sigmoid')
])

sadness_model.compile(optimizer=tf.keras.optimizers.RMSprop(lr=0.001),
             loss=tf.keras.losses.binary_crossentropy,
             metrics=[tf.keras.metrics.binary_accuracy]
             )

sadness_model.fit(x_sadness_train, y_sadness_train, epochs=50, batch_size=512)
sadness_results = sadness_model.evaluate(x_sadness_test, y_sadness_test)
sadness_review = "너무 화난다"
sadness_token = sadness_tokenize(sadness_review)

tf = sadness_term_frequency(sadness_token)
data = np.expand_dims(np.asarray(tf).astype('float32'),axis=0)
float(sadness_model.predict(data))

#neutral emotion

import pandas as pd
train_neutral_df = pd.read_csv("neutraltrainalldata.txt","\t")
test_neutral_df = pd.read_csv("neutraltestalldata.txt","\t")

from konlpy.tag import Okt
okt_neutral = Okt()

def neutral_tokenize(doc):
    return ['/'.join(t) for t in okt_neutral.pos(doc, norm=True, stem=True)]

train_neutral_df.isnull().any()
train_neutral_df['document'] = train_neutral_df['document'].fillna('');
test_neutral_df.isnull().any()
test_neutral_df['document'] = test_neutral_df['document'].fillna('');

train_neutral_docs = [(neutral_tokenize(row[1]), row[2]) for row in train_neutral_df.values]
test_neutral_docs = [(neutral_tokenize(row[1]),row[2]) for row in test_neutral_df.values]

tokens = [t for d in train_neutral_docs for t in d[0]]

import nltk
neutral_text = nltk.Text(tokens, name='NEUT')
#print(len(neutral_text.tokens))
#print(len(set(neutral_text.tokens)))
#print(neutral_text.vocab().most_common(10))

NEUTRAL_FREQUENCY_COUNT = 2000; #variable
neutral_selected_words = [f[0] for f in neutral_text.vocab().most_common(NEUTRAL_FREQUENCY_COUNT)]

def neutral_term_frequency(doc):
    return [doc.count(word) for word in neutral_selected_words]

x_neutral_train = [neutral_term_frequency(d) for d,_ in train_neutral_docs]
x_neutral_test = [neutral_term_frequency(d) for d,_ in test_neutral_docs]
y_neutral_train = [c for _,c in train_neutral_docs]
y_neutral_test = [c for _,c in test_neutral_docs]

import numpy as np
x_neutral_train = np.asarray(x_neutral_train).astype('float32')
x_neutral_test = np.asarray(x_neutral_test). astype('float32')

y_neutral_train = np.asarray(y_neutral_train).astype('float32')
y_neutral_test = np.asarray(y_neutral_test).astype('float32')

import tensorflow as tf
neutral_model= tf.keras.models.Sequential([
    tf.keras.layers.Dense(64, activation = 'relu',input_shape=(NEUTRAL_FREQUENCY_COUNT,)),
    tf.keras.layers.Dense(64, activation = 'relu'),
    tf.keras.layers.Dense(1, activation = 'sigmoid')
])

neutral_model.compile(optimizer=tf.keras.optimizers.RMSprop(lr=0.001),
             loss=tf.keras.losses.binary_crossentropy,
             metrics=[tf.keras.metrics.binary_accuracy]
             )

neutral_model.fit(x_neutral_train, y_neutral_train, epochs=50, batch_size=512)
neutral_results = neutral_model.evaluate(x_neutral_test, y_neutral_test)
neutral_review = "너무 화난다"
neutral_token = neutral_tokenize(neutral_review)

tf = neutral_term_frequency(neutral_token)
data = np.expand_dims(np.asarray(tf).astype('float32'),axis=0)
float(neutral_model.predict(data))

# happy emotion

import pandas as pd
train_happy_df = pd.read_csv("happytrainalldata.txt","\t")
test_happy_df = pd.read_csv("happytestalldata.txt","\t")

from konlpy.tag import Okt
okt_happy = Okt()

def happy_tokenize(doc):
    return ['/'.join(t) for t in okt_happy.pos(doc, norm=True, stem=True)]

train_happy_df.isnull().any()
train_happy_df['document'] = train_happy_df['document'].fillna('');
test_happy_df.isnull().any()
test_happy_df['document'] = test_happy_df['document'].fillna('');

train_happy_docs = [(happy_tokenize(row[1]), row[2]) for row in train_happy_df.values]
test_happy_docs = [(happy_tokenize(row[1]),row[2]) for row in test_happy_df.values]

tokens = [t for d in train_happy_docs for t in d[0]]

import nltk
happy_text = nltk.Text(tokens, name='HAPP')
#print(len(happy_text.tokens))
#print(len(set(happy_text.tokens)))
#print(happy_text.vocab().most_common(10))

HAPPY_FREQUENCY_COUNT = 2000; #variable
happy_selected_words = [f[0] for f in happy_text.vocab().most_common(HAPPY_FREQUENCY_COUNT)]

def happy_term_frequency(doc):
    return [doc.count(word) for word in happy_selected_words]

x_happy_train = [happy_term_frequency(d) for d,_ in train_happy_docs]
x_happy_test = [happy_term_frequency(d) for d,_ in test_happy_docs]
y_happy_train = [c for _,c in train_happy_docs]
y_happy_test = [c for _,c in test_happy_docs]

import numpy as np
x_happy_train = np.asarray(x_happy_train).astype('float32')
x_happy_test = np.asarray(x_happy_test). astype('float32')

y_happy_train = np.asarray(y_happy_train).astype('float32')
y_happy_test = np.asarray(y_happy_test).astype('float32')

import tensorflow as tf
happy_model= tf.keras.models.Sequential([
    tf.keras.layers.Dense(64, activation = 'relu',input_shape=(HAPPY_FREQUENCY_COUNT,)),
    tf.keras.layers.Dense(64, activation = 'relu'),
    tf.keras.layers.Dense(1, activation = 'sigmoid')
])
happy_model.compile(optimizer=tf.keras.optimizers.RMSprop(lr=0.001),
             loss=tf.keras.losses.binary_crossentropy,
             metrics=[tf.keras.metrics.binary_accuracy]
             )

happy_model.fit(x_happy_train, y_happy_train, epochs=50, batch_size=512)
happy_results = happy_model.evaluate(x_happy_test, y_happy_test)

happy_review = "너무 화난다"
happy_token = happy_tokenize(happy_review)

tf = happy_term_frequency(happy_token)
data = np.expand_dims(np.asarray(tf).astype('float32'),axis=0)
float(happy_model.predict(data))

#disgust emotion

import pandas as pd
train_disgust_df = pd.read_csv("disgusttrainalldata.txt","\t")
test_disgust_df = pd.read_csv("disgusttestalldata.txt","\t")

from konlpy.tag import Okt
okt_disgust = Okt()

def disgust_tokenize(doc):
    return ['/'.join(t) for t in okt_disgust.pos(doc, norm=True, stem=True)]

train_disgust_df.isnull().any()
train_disgust_df['document'] = train_disgust_df['document'].fillna('');
test_disgust_df.isnull().any()
test_disgust_df['document'] = test_disgust_df['document'].fillna('');

train_disgust_docs = [(disgust_tokenize(row[1]), row[2]) for row in train_disgust_df.values]
test_disgust_docs = [(disgust_tokenize(row[1]),row[2]) for row in test_disgust_df.values]

tokens = [t for d in train_disgust_docs for t in d[0]]

import nltk
disgust_text = nltk.Text(tokens, name='DISG')
#print(len(disgust_text.tokens))
#print(len(set(disgust_text.tokens)))
#print(disgust_text.vocab().most_common(10))

DISGUST_FREQUENCY_COUNT = 2000; #variable
disgust_selected_words = [f[0] for f in disgust_text.vocab().most_common(DISGUST_FREQUENCY_COUNT)]

def disgust_term_frequency(doc):
    return [doc.count(word) for word in disgust_selected_words]

x_disgust_train = [disgust_term_frequency(d) for d,_ in train_disgust_docs]
x_disgust_test = [disgust_term_frequency(d) for d,_ in test_disgust_docs]
y_disgust_train = [c for _,c in train_disgust_docs]
y_disgust_test = [c for _,c in test_disgust_docs]

import numpy as np
x_disgust_train = np.asarray(x_disgust_train).astype('float32')
x_disgust_test = np.asarray(x_disgust_test). astype('float32')

y_disgust_train = np.asarray(y_disgust_train).astype('float32')
y_disgust_test = np.asarray(y_disgust_test).astype('float32')

import tensorflow as tf
disgust_model= tf.keras.models.Sequential([
    tf.keras.layers.Dense(64, activation = 'relu',input_shape=(DISGUST_FREQUENCY_COUNT,)),
    tf.keras.layers.Dense(64, activation = 'relu'),
    tf.keras.layers.Dense(1, activation = 'sigmoid')
])
disgust_model.compile(optimizer=tf.keras.optimizers.RMSprop(lr=0.001),
             loss=tf.keras.losses.binary_crossentropy,
             metrics=[tf.keras.metrics.binary_accuracy]
             )
disgust_model.fit(x_disgust_train, y_disgust_train, epochs=50, batch_size=512)
disgust_results = neutral_model.evaluate(x_disgust_test, y_disgust_test)
disgust_review = "너무 화난다"
disgust_token = disgust_tokenize(disgust_review)

tf = disgust_term_frequency(disgust_token)
data = np.expand_dims(np.asarray(tf).astype('float32'),axis=0)
float(disgust_model.predict(data))

#function

import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
 
from math import pi
from matplotlib.path import Path
from matplotlib.spines import Spine
from matplotlib.transforms import Affine2D
    
def predict(predict):
    fear_token = fear_tokenize(predict)
    fear_tfq = fear_term_frequency(fear_token)
    fear_data = np.expand_dims(np.asarray(fear_tfq).astype('float32'), axis=0)
    fear_score = float(fear_model.predict(fear_data))
    #print(f"공포({round(fear_score*100)}%)")
    fear = round(fear_score*100)
    surprise_token = surprise_tokenize(predict)
    surprise_tfq = surprise_term_frequency(surprise_token)
    surprise_data = np.expand_dims(np.asarray(surprise_tfq).astype('float32'), axis=0)
    surprise_score = float(surprise_model.predict(surprise_data))
    #print(f"놀람({round(surprise_score*100)}%)")
    surprise = round(surprise_score*100)
    anger_token = anger_tokenize(predict)
    anger_tfq = anger_term_frequency(anger_token)
    anger_data = np.expand_dims(np.asarray(anger_tfq).astype('float32'), axis=0)
    anger_score = float(anger_model.predict(anger_data))
    #print(f"분노({round(anger_score*100)}%)")
    anger = round(anger_score*100)
    sadness_token = sadness_tokenize(predict)
    sadness_tfq = sadness_term_frequency(sadness_token)
    sadness_data = np.expand_dims(np.asarray(sadness_tfq).astype('float32'), axis=0)
    sadness_score = float(sadness_model.predict(sadness_data))
    #print(f"슬픔({round(sadness_score*100)}%)")
    sadness = round(sadness_score*100)
    neutral_token = neutral_tokenize(predict)
    neutral_tfq = neutral_term_frequency(neutral_token)
    neutral_data = np.expand_dims(np.asarray(neutral_tfq).astype('float32'), axis=0)
    neutral_score = float(neutral_model.predict(neutral_data))
    #print(f"중립({round(neutral_score*100)}%)")
    neutral = round(neutral_score*100)
    happy_token = happy_tokenize(predict)
    happy_tfq = happy_term_frequency(happy_token)
    happy_data = np.expand_dims(np.asarray(happy_tfq).astype('float32'), axis=0)
    happy_score = float(happy_model.predict(happy_data))
    #print(f"행복({round(happy_score*100)}%)")
    happy = round(happy_score*100)
    disgust_token = disgust_tokenize(predict)
    disgust_tfq = disgust_term_frequency(disgust_token)
    disgust_data = np.expand_dims(np.asarray(disgust_tfq).astype('float32'), axis=0)
    disgust_score = float(disgust_model.predict(disgust_data))
    #print(f"혐오({round(disgust_score*100)}%)")
    disgust = round(disgust_score*100)
    total = fear+disgust+sadness+happy+anger+neutral+surprise
 
    ## set data
    df = pd.DataFrame({
    'Character': ['RESULT'],
    'Fear': [round(100/(total)*fear)],
    'Disgust': [round(100/(total)*disgust)],
    'Sadness': [round(100/(total)*sadness)],
    'Happy': [round(100/(total)*happy)],
    'Angry': [round(100/(total)*anger)],
    'Neutral': [round(100/(total)*neutral)],
    'Surprise': [round(100/(total)*surprise)],
    })
    labels = df.columns[1:]
    num_labels = len(labels)
    
    angles = [x/float(num_labels)*(2*pi) for x in range(num_labels)] ## 각 등분점
    angles += angles[:1] ## 시작점으로 다시 돌아와야하므로 시작점 추가
    
    my_palette = plt.cm.get_cmap("Set2", len(df.index))
 
    fig = plt.figure(figsize=(15,20))
    fig.set_facecolor('white')
 
    for i, row in df.iterrows():
        color = my_palette(i)
        data = df.iloc[i].drop('Character').tolist()
        data += data[:1]
    
        ax = plt.subplot(3,2,i+1, polar=True)
        ax.set_theta_offset(pi / 2) ## 시작점
        ax.set_theta_direction(-1) ## 그려지는 방향 시계방향
    
        plt.xticks(angles[:-1], labels, fontsize=13) ## x축 눈금 라벨
        ax.tick_params(axis='x', which='major', pad=15) ## x축과 눈금 사이에 여백을 준다.
 
        ax.set_rlabel_position(0) ## y축 각도 설정(degree 단위)
        plt.yticks([0,20,40,60,80,100],['0','20','40','60','80','100'], fontsize=10) ## y축 눈금 설정
        plt.ylim(0,100)
    
        ax.plot(angles, data, color=color, linewidth=2, linestyle='solid') ## 레이더 차트 출력
        ax.fill(angles, data, color=color, alpha=0.4) ## 도형 안쪽에 색을 채워준다.
    
        plt.title(row.Character, size=20, color=color,x=-0.2, y=1.2, ha='left') ## 타이틀은 캐릭터 클래스로 한다.
 
        plt.tight_layout(pad=5) ## subplot간 패딩 조절
        plt.show()

    print(f"공포({round(100/(total)*fear)}%)")
    print(f"혐오({round(100/(total)*disgust)}%)")
    print(f"슬픔({round(100/(total)*sadness)}%)")
    print(f"행복({round(100/(total)*happy)}%)")
    print(f"분노({round(100/(total)*anger)}%)")
    print(f"중립({round(100/(total)*neutral)}%)")
    print(f"놀람({round(100/(total)*surprise)}%)")
# Out:
# Epoch 1/50
# 53/53 [==============================] - 0s 6ms/step - loss: 0.4243 - binary_accuracy: 0.8528
# Epoch 2/50
# 53/53 [==============================] - 0s 6ms/step - loss: 0.3162 - binary_accuracy: 0.8681
# Epoch 3/50
# 53/53 [==============================] - 0s 6ms/step - loss: 0.2845 - binary_accuracy: 0.8855
# Epoch 4/50
# 53/53 [==============================] - 0s 7ms/step - loss: 0.2659 - binary_accuracy: 0.8933
# Epoch 5/50
# 53/53 [==============================] - 0s 7ms/step - loss: 0.2512 - binary_accuracy: 0.8992
# Epoch 6/50
# 53/53 [==============================] - 0s 7ms/step - loss: 0.2372 - binary_accuracy: 0.9057
# Epoch 7/50
# 53/53 [==============================] - 0s 7ms/step - loss: 0.2226 - binary_accuracy: 0.9126
# Epoch 8/50
# 53/53 [==============================] - 0s 6ms/step - loss: 0.2071 - binary_accuracy: 0.9204
# Epoch 9/50
# 53/53 [==============================] - 0s 7ms/step - loss: 0.1916 - binary_accuracy: 0.9277
# Epoch 10/50
# 53/53 [==============================] - 0s 7ms/step - loss: 0.1758 - binary_accuracy: 0.9340
# Epoch 11/50
# 53/53 [==============================] - 0s 6ms/step - loss: 0.1592 - binary_accuracy: 0.9423
# Epoch 12/50
# 53/53 [==============================] - 0s 6ms/step - loss: 0.1429 - binary_accuracy: 0.9499
# Epoch 13/50
# 53/53 [==============================] - 0s 8ms/step - loss: 0.1261 - binary_accuracy: 0.9561
# Epoch 14/50
# 53/53 [==============================] - 0s 7ms/step - loss: 0.1099 - binary_accuracy: 0.9627
# Epoch 15/50
# 53/53 [==============================] - 0s 6ms/step - loss: 0.0946 - binary_accuracy: 0.9689
# Epoch 16/50
# 53/53 [==============================] - 0s 7ms/step - loss: 0.0805 - binary_accuracy: 0.9746
# Epoch 17/50
# 53/53 [==============================] - 0s 6ms/step - loss: 0.0672 - binary_accuracy: 0.9787
# Epoch 18/50
# 53/53 [==============================] - 0s 6ms/step - loss: 0.0570 - binary_accuracy: 0.9825
# Epoch 19/50
# 53/53 [==============================] - 0s 6ms/step - loss: 0.0478 - binary_accuracy: 0.9857
# Epoch 20/50
# 53/53 [==============================] - 0s 6ms/step - loss: 0.0399 - binary_accuracy: 0.9883
# Epoch 21/50
# 53/53 [==============================] - 0s 8ms/step - loss: 0.0347 - binary_accuracy: 0.9893
# Epoch 22/50
# 53/53 [==============================] - 0s 7ms/step - loss: 0.0294 - binary_accuracy: 0.9912
# Epoch 23/50
# 53/53 [==============================] - 0s 6ms/step - loss: 0.0255 - binary_accuracy: 0.9925
# Epoch 24/50
# 53/53 [==============================] - 0s 6ms/step - loss: 0.0218 - binary_accuracy: 0.9935
# Epoch 25/50
# 53/53 [==============================] - 0s 6ms/step - loss: 0.0188 - binary_accuracy: 0.9945
# Epoch 26/50
# 53/53 [==============================] - 0s 6ms/step - loss: 0.0166 - binary_accuracy: 0.9950
# Epoch 27/50
# 53/53 [==============================] - 0s 9ms/step - loss: 0.0145 - binary_accuracy: 0.9956
# Epoch 28/50
# 53/53 [==============================] - 0s 6ms/step - loss: 0.0130 - binary_accuracy: 0.9960
# Epoch 29/50
# 53/53 [==============================] - 0s 6ms/step - loss: 0.0118 - binary_accuracy: 0.9964
# Epoch 30/50
# 53/53 [==============================] - 0s 7ms/step - loss: 0.0111 - binary_accuracy: 0.9965
# Epoch 31/50
# 53/53 [==============================] - 0s 6ms/step - loss: 0.0096 - binary_accuracy: 0.9970
# Epoch 32/50
# 53/53 [==============================] - 0s 6ms/step - loss: 0.0096 - binary_accuracy: 0.9970
# Epoch 33/50
# 53/53 [==============================] - 0s 6ms/step - loss: 0.0089 - binary_accuracy: 0.9972
# Epoch 34/50
# 53/53 [==============================] - 0s 6ms/step - loss: 0.0086 - binary_accuracy: 0.9971
# Epoch 35/50
# 53/53 [==============================] - 0s 6ms/step - loss: 0.0084 - binary_accuracy: 0.9971
# Epoch 36/50
# 53/53 [==============================] - 0s 6ms/step - loss: 0.0078 - binary_accuracy: 0.9970
# Epoch 37/50
# 53/53 [==============================] - 0s 6ms/step - loss: 0.0079 - binary_accuracy: 0.9971
# Epoch 38/50
# 53/53 [==============================] - 0s 6ms/step - loss: 0.0076 - binary_accuracy: 0.9970
# Epoch 39/50
# 53/53 [==============================] - 0s 7ms/step - loss: 0.0074 - binary_accuracy: 0.9971
# Epoch 40/50
# 53/53 [==============================] - 0s 6ms/step - loss: 0.0071 - binary_accuracy: 0.9974
# Epoch 41/50
# 53/53 [==============================] - 0s 6ms/step - loss: 0.0069 - binary_accuracy: 0.9976
# Epoch 42/50
# 53/53 [==============================] - 0s 6ms/step - loss: 0.0069 - binary_accuracy: 0.9975
# Epoch 43/50
# 53/53 [==============================] - 0s 6ms/step - loss: 0.0070 - binary_accuracy: 0.9976
# Epoch 44/50
# 53/53 [==============================] - 0s 6ms/step - loss: 0.0068 - binary_accuracy: 0.9976
# Epoch 45/50
# 53/53 [==============================] - 0s 6ms/step - loss: 0.0066 - binary_accuracy: 0.9972
# Epoch 46/50
# 53/53 [==============================] - 0s 6ms/step - loss: 0.0068 - binary_accuracy: 0.9973
# Epoch 47/50
# 53/53 [==============================] - 0s 6ms/step - loss: 0.0066 - binary_accuracy: 0.9974
# Epoch 48/50
# 53/53 [==============================] - 0s 7ms/step - loss: 0.0063 - binary_accuracy: 0.9974
# Epoch 49/50
# 53/53 [==============================] - 0s 6ms/step - loss: 0.0067 - binary_accuracy: 0.9974
# Epoch 50/50
# 53/53 [==============================] - 0s 6ms/step - loss: 0.0064 - binary_accuracy: 0.9975
# 362/362 [==============================] - 1s 1ms/step - loss: 1.6446 - binary_accuracy: 0.8368
# Epoch 1/50
# 53/53 [==============================] - 2s 40ms/step - loss: 0.4447 - binary_accuracy: 0.8367
# Epoch 2/50
# 53/53 [==============================] - 1s 11ms/step - loss: 0.3499 - binary_accuracy: 0.8515
# Epoch 3/50
# 53/53 [==============================] - 0s 7ms/step - loss: 0.3178 - binary_accuracy: 0.8666
# Epoch 4/50
# 53/53 [==============================] - 0s 7ms/step - loss: 0.2997 - binary_accuracy: 0.8738
# Epoch 5/50
# 53/53 [==============================] - 0s 7ms/step - loss: 0.2852 - binary_accuracy: 0.8810
# Epoch 6/50
# 53/53 [==============================] - 0s 7ms/step - loss: 0.2718 - binary_accuracy: 0.8884
# Epoch 7/50
# 53/53 [==============================] - 0s 7ms/step - loss: 0.2579 - binary_accuracy: 0.8951
# Epoch 8/50
# 53/53 [==============================] - 0s 7ms/step - loss: 0.2431 - binary_accuracy: 0.9027
# Epoch 9/50
# 53/53 [==============================] - 0s 7ms/step - loss: 0.2282 - binary_accuracy: 0.9092
# Epoch 10/50
# 53/53 [==============================] - 0s 7ms/step - loss: 0.2125 - binary_accuracy: 0.9171
# Epoch 11/50
# 53/53 [==============================] - 0s 7ms/step - loss: 0.1964 - binary_accuracy: 0.9231
# Epoch 12/50
# 53/53 [==============================] - 0s 7ms/step - loss: 0.1797 - binary_accuracy: 0.9317
# Epoch 13/50
# 53/53 [==============================] - 0s 7ms/step - loss: 0.1623 - binary_accuracy: 0.9381
# Epoch 14/50
# 53/53 [==============================] - 0s 7ms/step - loss: 0.1457 - binary_accuracy: 0.9464
# Epoch 15/50
# 53/53 [==============================] - 0s 7ms/step - loss: 0.1281 - binary_accuracy: 0.9551
# Epoch 16/50
# 53/53 [==============================] - 0s 7ms/step - loss: 0.1114 - binary_accuracy: 0.9617
# Epoch 17/50
# 53/53 [==============================] - 0s 7ms/step - loss: 0.0968 - binary_accuracy: 0.9670
# Epoch 18/50
# 53/53 [==============================] - 0s 8ms/step - loss: 0.0834 - binary_accuracy: 0.9728
# Epoch 19/50
# 53/53 [==============================] - 0s 7ms/step - loss: 0.0710 - binary_accuracy: 0.9771
# Epoch 20/50
# 53/53 [==============================] - 0s 6ms/step - loss: 0.0606 - binary_accuracy: 0.9796
# Epoch 21/50
# 53/53 [==============================] - 0s 7ms/step - loss: 0.0513 - binary_accuracy: 0.9830
# Epoch 22/50
# 53/53 [==============================] - 0s 7ms/step - loss: 0.0436 - binary_accuracy: 0.9861
# Epoch 23/50
# 53/53 [==============================] - 0s 7ms/step - loss: 0.0373 - binary_accuracy: 0.9877
# Epoch 24/50
# 53/53 [==============================] - 0s 7ms/step - loss: 0.0320 - binary_accuracy: 0.9897
# Epoch 25/50
# 53/53 [==============================] - 0s 8ms/step - loss: 0.0275 - binary_accuracy: 0.9909A: 0s - loss: 0.0254 - binary_accuracy: 0.9
# Epoch 26/50
# 53/53 [==============================] - 0s 6ms/step - loss: 0.0240 - binary_accuracy: 0.9924
# Epoch 27/50
# 53/53 [==============================] - 0s 7ms/step - loss: 0.0210 - binary_accuracy: 0.9931
# Epoch 28/50
# 53/53 [==============================] - 0s 7ms/step - loss: 0.0187 - binary_accuracy: 0.9936
# Epoch 29/50
# 53/53 [==============================] - 0s 7ms/step - loss: 0.0169 - binary_accuracy: 0.9941
# Epoch 30/50
# 53/53 [==============================] - 0s 7ms/step - loss: 0.0148 - binary_accuracy: 0.9947
# Epoch 31/50
# 53/53 [==============================] - 0s 7ms/step - loss: 0.0137 - binary_accuracy: 0.9949
# Epoch 32/50
# 53/53 [==============================] - 0s 7ms/step - loss: 0.0131 - binary_accuracy: 0.9953
# Epoch 33/50
# 53/53 [==============================] - 0s 7ms/step - loss: 0.0120 - binary_accuracy: 0.9956
# Epoch 34/50
# 53/53 [==============================] - 0s 6ms/step - loss: 0.0111 - binary_accuracy: 0.9955
# Epoch 35/50
# 53/53 [==============================] - 0s 7ms/step - loss: 0.0106 - binary_accuracy: 0.9956
# Epoch 36/50
# 53/53 [==============================] - 0s 7ms/step - loss: 0.0102 - binary_accuracy: 0.9958
# Epoch 37/50
# 53/53 [==============================] - 0s 6ms/step - loss: 0.0097 - binary_accuracy: 0.9963
# Epoch 38/50
# 53/53 [==============================] - 0s 7ms/step - loss: 0.0089 - binary_accuracy: 0.9963
# Epoch 39/50
# 53/53 [==============================] - 0s 6ms/step - loss: 0.0090 - binary_accuracy: 0.9963
# Epoch 40/50
# 53/53 [==============================] - 0s 7ms/step - loss: 0.0088 - binary_accuracy: 0.9962
# Epoch 41/50
# 53/53 [==============================] - 0s 7ms/step - loss: 0.0087 - binary_accuracy: 0.9966
# Epoch 42/50
# 53/53 [==============================] - 0s 6ms/step - loss: 0.0083 - binary_accuracy: 0.9966
# Epoch 43/50
# 53/53 [==============================] - 0s 7ms/step - loss: 0.0082 - binary_accuracy: 0.9966
# Epoch 44/50
# 53/53 [==============================] - 0s 7ms/step - loss: 0.0084 - binary_accuracy: 0.9964
# Epoch 45/50
# 53/53 [==============================] - 0s 7ms/step - loss: 0.0080 - binary_accuracy: 0.9965
# Epoch 46/50
# 53/53 [==============================] - 0s 7ms/step - loss: 0.0079 - binary_accuracy: 0.9967
# Epoch 47/50
# 53/53 [==============================] - 0s 7ms/step - loss: 0.0077 - binary_accuracy: 0.9967
# Epoch 48/50
# 53/53 [==============================] - 0s 7ms/step - loss: 0.0082 - binary_accuracy: 0.9964
# Epoch 49/50
# 53/53 [==============================] - 0s 7ms/step - loss: 0.0077 - binary_accuracy: 0.9966
# Epoch 50/50
# 53/53 [==============================] - 0s 7ms/step - loss: 0.0074 - binary_accuracy: 0.9968
# 362/362 [==============================] - 1s 1ms/step - loss: 1.8169 - binary_accuracy: 0.8165
# Epoch 1/50
# 53/53 [==============================] - 2s 33ms/step - loss: 0.4350 - binary_accuracy: 0.8467
# Epoch 2/50
# 53/53 [==============================] - 0s 8ms/step - loss: 0.3279 - binary_accuracy: 0.8602
# Epoch 3/50
# 53/53 [==============================] - 0s 7ms/step - loss: 0.2979 - binary_accuracy: 0.8731
# Epoch 4/50
# 53/53 [==============================] - 0s 7ms/step - loss: 0.2800 - binary_accuracy: 0.8815
# Epoch 5/50
# 53/53 [==============================] - 0s 7ms/step - loss: 0.2644 - binary_accuracy: 0.8897
# Epoch 6/50
# 53/53 [==============================] - 0s 7ms/step - loss: 0.2490 - binary_accuracy: 0.8978
# Epoch 7/50
# 53/53 [==============================] - 0s 7ms/step - loss: 0.2324 - binary_accuracy: 0.9060
# Epoch 8/50
# 53/53 [==============================] - 0s 7ms/step - loss: 0.2153 - binary_accuracy: 0.9145
# Epoch 9/50
# 53/53 [==============================] - 0s 7ms/step - loss: 0.1981 - binary_accuracy: 0.9241
# Epoch 10/50
# 53/53 [==============================] - 0s 7ms/step - loss: 0.1796 - binary_accuracy: 0.9330
# Epoch 11/50
# 53/53 [==============================] - 0s 7ms/step - loss: 0.1613 - binary_accuracy: 0.9416
# Epoch 12/50
# 53/53 [==============================] - 0s 7ms/step - loss: 0.1424 - binary_accuracy: 0.9504
# Epoch 13/50
# 53/53 [==============================] - 0s 7ms/step - loss: 0.1246 - binary_accuracy: 0.9572
# Epoch 14/50
# 53/53 [==============================] - 0s 7ms/step - loss: 0.1063 - binary_accuracy: 0.9658
# Epoch 15/50
# 53/53 [==============================] - 0s 7ms/step - loss: 0.0891 - binary_accuracy: 0.9718
# Epoch 16/50
# 53/53 [==============================] - 0s 7ms/step - loss: 0.0746 - binary_accuracy: 0.9769
# Epoch 17/50
# 53/53 [==============================] - 0s 7ms/step - loss: 0.0615 - binary_accuracy: 0.9825
# Epoch 18/50
# 53/53 [==============================] - 0s 8ms/step - loss: 0.0497 - binary_accuracy: 0.9860
# Epoch 19/50
# 53/53 [==============================] - 0s 7ms/step - loss: 0.0401 - binary_accuracy: 0.9891
# Epoch 20/50
# 53/53 [==============================] - 0s 7ms/step - loss: 0.0328 - binary_accuracy: 0.9907
# Epoch 21/50
# 53/53 [==============================] - 0s 7ms/step - loss: 0.0268 - binary_accuracy: 0.9928
# Epoch 22/50
# 53/53 [==============================] - 0s 7ms/step - loss: 0.0214 - binary_accuracy: 0.9938
# Epoch 23/50
# 53/53 [==============================] - 0s 7ms/step - loss: 0.0177 - binary_accuracy: 0.9952
# Epoch 24/50
# 53/53 [==============================] - 0s 7ms/step - loss: 0.0146 - binary_accuracy: 0.9961
# Epoch 25/50
# 53/53 [==============================] - 0s 7ms/step - loss: 0.0125 - binary_accuracy: 0.9966
# Epoch 26/50
# 53/53 [==============================] - 0s 7ms/step - loss: 0.0109 - binary_accuracy: 0.9966
# Epoch 27/50
# 53/53 [==============================] - 0s 7ms/step - loss: 0.0095 - binary_accuracy: 0.9971
# Epoch 28/50
# 53/53 [==============================] - 0s 8ms/step - loss: 0.0080 - binary_accuracy: 0.9975
# Epoch 29/50
# 53/53 [==============================] - 0s 7ms/step - loss: 0.0074 - binary_accuracy: 0.9976
# Epoch 30/50
# 53/53 [==============================] - 0s 8ms/step - loss: 0.0066 - binary_accuracy: 0.9978
# Epoch 31/50
# 53/53 [==============================] - 0s 8ms/step - loss: 0.0060 - binary_accuracy: 0.9978
# Epoch 32/50
# 53/53 [==============================] - 0s 8ms/step - loss: 0.0059 - binary_accuracy: 0.9978
# Epoch 33/50
# 53/53 [==============================] - 0s 8ms/step - loss: 0.0055 - binary_accuracy: 0.9978
# Epoch 34/50
# 53/53 [==============================] - 0s 8ms/step - loss: 0.0053 - binary_accuracy: 0.9979
# Epoch 35/50
# 53/53 [==============================] - 0s 8ms/step - loss: 0.0049 - binary_accuracy: 0.9981
# Epoch 36/50
# 53/53 [==============================] - 0s 7ms/step - loss: 0.0049 - binary_accuracy: 0.9983
# Epoch 37/50
# 53/53 [==============================] - 0s 7ms/step - loss: 0.0046 - binary_accuracy: 0.9981
# Epoch 38/50
# 53/53 [==============================] - 0s 7ms/step - loss: 0.0046 - binary_accuracy: 0.9983
# Epoch 39/50
# 53/53 [==============================] - 0s 7ms/step - loss: 0.0047 - binary_accuracy: 0.9981
# Epoch 40/50
# 53/53 [==============================] - 0s 7ms/step - loss: 0.0047 - binary_accuracy: 0.9981
# Epoch 41/50
# 53/53 [==============================] - 0s 7ms/step - loss: 0.0044 - binary_accuracy: 0.9983
# Epoch 42/50
# 53/53 [==============================] - 0s 7ms/step - loss: 0.0047 - binary_accuracy: 0.9981
# Epoch 43/50
# 53/53 [==============================] - 0s 8ms/step - loss: 0.0044 - binary_accuracy: 0.9983
# Epoch 44/50
# 53/53 [==============================] - 0s 7ms/step - loss: 0.0043 - binary_accuracy: 0.9982
# Epoch 45/50
# 53/53 [==============================] - 0s 8ms/step - loss: 0.0042 - binary_accuracy: 0.9984
# Epoch 46/50
# 53/53 [==============================] - 0s 7ms/step - loss: 0.0042 - binary_accuracy: 0.9985
# Epoch 47/50
# 53/53 [==============================] - 0s 7ms/step - loss: 0.0042 - binary_accuracy: 0.9983
# Epoch 48/50
# 53/53 [==============================] - 0s 7ms/step - loss: 0.0042 - binary_accuracy: 0.9982
# Epoch 49/50
# 53/53 [==============================] - 0s 7ms/step - loss: 0.0043 - binary_accuracy: 0.9983
# Epoch 50/50
# 53/53 [==============================] - 0s 7ms/step - loss: 0.0039 - binary_accuracy: 0.9983
# 362/362 [==============================] - 1s 2ms/step - loss: 2.1205 - binary_accuracy: 0.8178
# Epoch 1/50
# 53/53 [==============================] - 2s 43ms/step - loss: 0.4130 - binary_accuracy: 0.8530
# Epoch 2/50
# 53/53 [==============================] - 1s 12ms/step - loss: 0.2812 - binary_accuracy: 0.8873
# Epoch 3/50
# 53/53 [==============================] - 0s 6ms/step - loss: 0.2431 - binary_accuracy: 0.9055
# Epoch 4/50
# 53/53 [==============================] - 0s 6ms/step - loss: 0.2230 - binary_accuracy: 0.9141
# Epoch 5/50
# 53/53 [==============================] - 0s 7ms/step - loss: 0.2073 - binary_accuracy: 0.9191
# Epoch 6/50
# 53/53 [==============================] - 0s 6ms/step - loss: 0.1924 - binary_accuracy: 0.9260
# Epoch 7/50
# 53/53 [==============================] - 0s 7ms/step - loss: 0.1780 - binary_accuracy: 0.9326
# Epoch 8/50
# 53/53 [==============================] - 0s 7ms/step - loss: 0.1629 - binary_accuracy: 0.9391
# Epoch 9/50
# 53/53 [==============================] - 0s 7ms/step - loss: 0.1482 - binary_accuracy: 0.9462
# Epoch 10/50
# 53/53 [==============================] - 0s 7ms/step - loss: 0.1344 - binary_accuracy: 0.9529
# Epoch 11/50
# 53/53 [==============================] - 0s 7ms/step - loss: 0.1204 - binary_accuracy: 0.9580
# Epoch 12/50
# 53/53 [==============================] - 0s 7ms/step - loss: 0.1071 - binary_accuracy: 0.9631
# Epoch 13/50
# 53/53 [==============================] - 0s 6ms/step - loss: 0.0943 - binary_accuracy: 0.9685
# Epoch 14/50
# 53/53 [==============================] - 0s 7ms/step - loss: 0.0814 - binary_accuracy: 0.9731
# Epoch 15/50
# 53/53 [==============================] - 0s 6ms/step - loss: 0.0694 - binary_accuracy: 0.9773
# Epoch 16/50
# 53/53 [==============================] - 0s 6ms/step - loss: 0.0577 - binary_accuracy: 0.9816
# Epoch 17/50
# 53/53 [==============================] - 0s 7ms/step - loss: 0.0475 - binary_accuracy: 0.9853
# Epoch 18/50
# 53/53 [==============================] - 0s 6ms/step - loss: 0.0391 - binary_accuracy: 0.9882
# Epoch 19/50
# 53/53 [==============================] - 0s 6ms/step - loss: 0.0312 - binary_accuracy: 0.9911
# Epoch 20/50
# 53/53 [==============================] - 0s 7ms/step - loss: 0.0255 - binary_accuracy: 0.9927
# Epoch 21/50
# 53/53 [==============================] - 0s 7ms/step - loss: 0.0213 - binary_accuracy: 0.9939
# Epoch 22/50
# 53/53 [==============================] - 0s 7ms/step - loss: 0.0179 - binary_accuracy: 0.9949
# Epoch 23/50
# 53/53 [==============================] - 0s 7ms/step - loss: 0.0147 - binary_accuracy: 0.9962
# Epoch 24/50
# 53/53 [==============================] - 0s 6ms/step - loss: 0.0128 - binary_accuracy: 0.9960
# Epoch 25/50
# 53/53 [==============================] - 0s 6ms/step - loss: 0.0111 - binary_accuracy: 0.9967
# Epoch 26/50
# 53/53 [==============================] - 0s 6ms/step - loss: 0.0096 - binary_accuracy: 0.9973
# Epoch 27/50
# 53/53 [==============================] - 0s 5ms/step - loss: 0.0086 - binary_accuracy: 0.9973
# Epoch 28/50
# 53/53 [==============================] - 0s 6ms/step - loss: 0.0075 - binary_accuracy: 0.9975
# Epoch 29/50
# 53/53 [==============================] - 0s 6ms/step - loss: 0.0069 - binary_accuracy: 0.9980
# Epoch 30/50
# 53/53 [==============================] - 0s 7ms/step - loss: 0.0069 - binary_accuracy: 0.9977
# Epoch 31/50
# 53/53 [==============================] - 0s 7ms/step - loss: 0.0063 - binary_accuracy: 0.9980
# Epoch 32/50
# 53/53 [==============================] - 0s 6ms/step - loss: 0.0058 - binary_accuracy: 0.9982
# Epoch 33/50
# 53/53 [==============================] - 0s 6ms/step - loss: 0.0059 - binary_accuracy: 0.9980
# Epoch 34/50
# 53/53 [==============================] - 0s 6ms/step - loss: 0.0054 - binary_accuracy: 0.9981
# Epoch 35/50
# 53/53 [==============================] - 0s 6ms/step - loss: 0.0056 - binary_accuracy: 0.9981
# Epoch 36/50
# 53/53 [==============================] - 0s 6ms/step - loss: 0.0053 - binary_accuracy: 0.9980
# Epoch 37/50
# 53/53 [==============================] - 0s 6ms/step - loss: 0.0052 - binary_accuracy: 0.9981
# Epoch 38/50
# 53/53 [==============================] - 0s 7ms/step - loss: 0.0051 - binary_accuracy: 0.9983
# Epoch 39/50
# 53/53 [==============================] - 0s 6ms/step - loss: 0.0049 - binary_accuracy: 0.9981
# Epoch 40/50
# 53/53 [==============================] - 0s 7ms/step - loss: 0.0049 - binary_accuracy: 0.9982
# Epoch 41/50
# 53/53 [==============================] - 0s 7ms/step - loss: 0.0049 - binary_accuracy: 0.9982
# Epoch 42/50
# 53/53 [==============================] - 0s 7ms/step - loss: 0.0048 - binary_accuracy: 0.9983
# Epoch 43/50
# 53/53 [==============================] - 0s 7ms/step - loss: 0.0049 - binary_accuracy: 0.9981
# Epoch 44/50
# 53/53 [==============================] - 0s 6ms/step - loss: 0.0051 - binary_accuracy: 0.9981
# Epoch 45/50
# 53/53 [==============================] - 0s 7ms/step - loss: 0.0047 - binary_accuracy: 0.9982
# Epoch 46/50
# 53/53 [==============================] - 0s 6ms/step - loss: 0.0048 - binary_accuracy: 0.9981
# Epoch 47/50
# 53/53 [==============================] - 0s 7ms/step - loss: 0.0047 - binary_accuracy: 0.9982
# Epoch 48/50
# 53/53 [==============================] - 0s 7ms/step - loss: 0.0043 - binary_accuracy: 0.9983
# Epoch 49/50
# 53/53 [==============================] - 0s 7ms/step - loss: 0.0048 - binary_accuracy: 0.9982
# Epoch 50/50
# 53/53 [==============================] - 0s 6ms/step - loss: 0.0046 - binary_accuracy: 0.9983
# 362/362 [==============================] - 1s 2ms/step - loss: 1.6540 - binary_accuracy: 0.8619
# Epoch 1/50
# 53/53 [==============================] - 2s 46ms/step - loss: 0.4146 - binary_accuracy: 0.8707
# Epoch 2/50
# 53/53 [==============================] - 1s 14ms/step - loss: 0.3325 - binary_accuracy: 0.8748
# Epoch 3/50
# 53/53 [==============================] - 0s 6ms/step - loss: 0.3092 - binary_accuracy: 0.8762
# Epoch 4/50
# 53/53 [==============================] - 0s 6ms/step - loss: 0.2930 - binary_accuracy: 0.8815
# Epoch 5/50
# 53/53 [==============================] - 0s 6ms/step - loss: 0.2788 - binary_accuracy: 0.8880
# Epoch 6/50
# 53/53 [==============================] - 0s 6ms/step - loss: 0.2638 - binary_accuracy: 0.8944
# Epoch 7/50
# 53/53 [==============================] - 0s 6ms/step - loss: 0.2477 - binary_accuracy: 0.9037
# Epoch 8/50
# 53/53 [==============================] - 0s 6ms/step - loss: 0.2303 - binary_accuracy: 0.9105
# Epoch 9/50
# 53/53 [==============================] - 0s 5ms/step - loss: 0.2127 - binary_accuracy: 0.9172
# Epoch 10/50
# 53/53 [==============================] - 0s 6ms/step - loss: 0.1949 - binary_accuracy: 0.9244
# Epoch 11/50
# 53/53 [==============================] - 0s 6ms/step - loss: 0.1764 - binary_accuracy: 0.9327
# Epoch 12/50
# 53/53 [==============================] - 0s 6ms/step - loss: 0.1579 - binary_accuracy: 0.9402
# Epoch 13/50
# 53/53 [==============================] - 0s 6ms/step - loss: 0.1393 - binary_accuracy: 0.9488
# Epoch 14/50
# 53/53 [==============================] - 0s 6ms/step - loss: 0.1207 - binary_accuracy: 0.9570
# Epoch 15/50
# 53/53 [==============================] - 0s 6ms/step - loss: 0.1040 - binary_accuracy: 0.9646
# Epoch 16/50
# 53/53 [==============================] - 0s 7ms/step - loss: 0.0872 - binary_accuracy: 0.9712
# Epoch 17/50
# 53/53 [==============================] - 0s 6ms/step - loss: 0.0735 - binary_accuracy: 0.9762
# Epoch 18/50
# 53/53 [==============================] - 0s 6ms/step - loss: 0.0606 - binary_accuracy: 0.9812
# Epoch 19/50
# 53/53 [==============================] - 0s 6ms/step - loss: 0.0508 - binary_accuracy: 0.9846
# Epoch 20/50
# 53/53 [==============================] - 0s 6ms/step - loss: 0.0419 - binary_accuracy: 0.9879
# Epoch 21/50
# 53/53 [==============================] - 0s 6ms/step - loss: 0.0346 - binary_accuracy: 0.9903
# Epoch 22/50
# 53/53 [==============================] - 0s 6ms/step - loss: 0.0290 - binary_accuracy: 0.9919
# Epoch 23/50
# 53/53 [==============================] - 0s 6ms/step - loss: 0.0240 - binary_accuracy: 0.9936
# Epoch 24/50
# 53/53 [==============================] - 0s 6ms/step - loss: 0.0203 - binary_accuracy: 0.9942
# Epoch 25/50
# 53/53 [==============================] - 0s 6ms/step - loss: 0.0172 - binary_accuracy: 0.9952
# Epoch 26/50
# 53/53 [==============================] - 0s 5ms/step - loss: 0.0147 - binary_accuracy: 0.9961
# Epoch 27/50
# 53/53 [==============================] - 0s 6ms/step - loss: 0.0131 - binary_accuracy: 0.9965
# Epoch 28/50
# 53/53 [==============================] - 0s 7ms/step - loss: 0.0115 - binary_accuracy: 0.9966
# Epoch 29/50
# 53/53 [==============================] - 0s 6ms/step - loss: 0.0104 - binary_accuracy: 0.9973
# Epoch 30/50
# 53/53 [==============================] - 0s 6ms/step - loss: 0.0092 - binary_accuracy: 0.9971
# Epoch 31/50
# 53/53 [==============================] - 0s 6ms/step - loss: 0.0089 - binary_accuracy: 0.9972
# Epoch 32/50
# 53/53 [==============================] - 0s 6ms/step - loss: 0.0079 - binary_accuracy: 0.9976
# Epoch 33/50
# 53/53 [==============================] - 0s 7ms/step - loss: 0.0078 - binary_accuracy: 0.9976
# Epoch 34/50
# 53/53 [==============================] - 0s 6ms/step - loss: 0.0072 - binary_accuracy: 0.9979
# Epoch 35/50
# 53/53 [==============================] - 0s 5ms/step - loss: 0.0072 - binary_accuracy: 0.9975
# Epoch 36/50
# 53/53 [==============================] - 0s 6ms/step - loss: 0.0065 - binary_accuracy: 0.9979
# Epoch 37/50
# 53/53 [==============================] - 0s 6ms/step - loss: 0.0066 - binary_accuracy: 0.9977
# Epoch 38/50
# 53/53 [==============================] - 0s 6ms/step - loss: 0.0062 - binary_accuracy: 0.9979
# Epoch 39/50
# 53/53 [==============================] - 0s 6ms/step - loss: 0.0061 - binary_accuracy: 0.9979
# Epoch 40/50
# 53/53 [==============================] - 0s 6ms/step - loss: 0.0059 - binary_accuracy: 0.9979
# Epoch 41/50
# 53/53 [==============================] - 0s 6ms/step - loss: 0.0061 - binary_accuracy: 0.9979
# Epoch 42/50
# 53/53 [==============================] - 0s 6ms/step - loss: 0.0059 - binary_accuracy: 0.9978
# Epoch 43/50
# 53/53 [==============================] - 0s 6ms/step - loss: 0.0056 - binary_accuracy: 0.9981
# Epoch 44/50
# 53/53 [==============================] - 0s 7ms/step - loss: 0.0056 - binary_accuracy: 0.9981
# Epoch 45/50
# 53/53 [==============================] - 0s 6ms/step - loss: 0.0056 - binary_accuracy: 0.9977
# Epoch 46/50
# 53/53 [==============================] - 0s 6ms/step - loss: 0.0058 - binary_accuracy: 0.9980
# Epoch 47/50
# 53/53 [==============================] - 0s 5ms/step - loss: 0.0055 - binary_accuracy: 0.9979
# Epoch 48/50
# 53/53 [==============================] - 0s 6ms/step - loss: 0.0058 - binary_accuracy: 0.9978
# Epoch 49/50
# 53/53 [==============================] - 0s 6ms/step - loss: 0.0054 - binary_accuracy: 0.9979
# Epoch 50/50
# 53/53 [==============================] - 0s 6ms/step - loss: 0.0056 - binary_accuracy: 0.9980
# 362/362 [==============================] - 1s 1ms/step - loss: 1.8147 - binary_accuracy: 0.8123
# Epoch 1/50
# 53/53 [==============================] - 2s 40ms/step - loss: 0.3926 - binary_accuracy: 0.8521
# Epoch 2/50
# 53/53 [==============================] - 1s 11ms/step - loss: 0.2226 - binary_accuracy: 0.9221
# Epoch 3/50
# 53/53 [==============================] - 0s 6ms/step - loss: 0.1844 - binary_accuracy: 0.9332
# Epoch 4/50
# 53/53 [==============================] - 0s 7ms/step - loss: 0.1680 - binary_accuracy: 0.9371
# Epoch 5/50
# 53/53 [==============================] - 0s 7ms/step - loss: 0.1566 - binary_accuracy: 0.9423
# Epoch 6/50
# 53/53 [==============================] - 0s 7ms/step - loss: 0.1477 - binary_accuracy: 0.9459
# Epoch 7/50
# 53/53 [==============================] - 0s 7ms/step - loss: 0.1395 - binary_accuracy: 0.9485
# Epoch 8/50
# 53/53 [==============================] - 0s 7ms/step - loss: 0.1315 - binary_accuracy: 0.9515
# Epoch 9/50
# 53/53 [==============================] - 0s 7ms/step - loss: 0.1231 - binary_accuracy: 0.9554
# Epoch 10/50
# 53/53 [==============================] - 0s 7ms/step - loss: 0.1151 - binary_accuracy: 0.9579
# Epoch 11/50
# 53/53 [==============================] - 0s 7ms/step - loss: 0.1069 - binary_accuracy: 0.9616
# Epoch 12/50
# 53/53 [==============================] - 0s 7ms/step - loss: 0.0993 - binary_accuracy: 0.9655
# Epoch 13/50
# 53/53 [==============================] - 0s 6ms/step - loss: 0.0910 - binary_accuracy: 0.9679
# Epoch 14/50
# 53/53 [==============================] - 0s 6ms/step - loss: 0.0833 - binary_accuracy: 0.9714
# Epoch 15/50
# 53/53 [==============================] - 0s 7ms/step - loss: 0.0753 - binary_accuracy: 0.9747
# Epoch 16/50
# 53/53 [==============================] - 0s 5ms/step - loss: 0.0672 - binary_accuracy: 0.9779
# Epoch 17/50
# 53/53 [==============================] - 0s 5ms/step - loss: 0.0591 - binary_accuracy: 0.9814
# Epoch 18/50
# 53/53 [==============================] - 0s 6ms/step - loss: 0.0517 - binary_accuracy: 0.9830
# Epoch 19/50
# 53/53 [==============================] - 0s 6ms/step - loss: 0.0446 - binary_accuracy: 0.9864
# Epoch 20/50
# 53/53 [==============================] - 0s 5ms/step - loss: 0.0383 - binary_accuracy: 0.9875
# Epoch 21/50
# 53/53 [==============================] - 0s 6ms/step - loss: 0.0324 - binary_accuracy: 0.9899
# Epoch 22/50
# 53/53 [==============================] - 0s 6ms/step - loss: 0.0273 - binary_accuracy: 0.9918
# Epoch 23/50
# 53/53 [==============================] - 0s 6ms/step - loss: 0.0237 - binary_accuracy: 0.9930
# Epoch 24/50
# 53/53 [==============================] - 0s 6ms/step - loss: 0.0203 - binary_accuracy: 0.9935
# Epoch 25/50
# 53/53 [==============================] - 0s 6ms/step - loss: 0.0177 - binary_accuracy: 0.9945
# Epoch 26/50
# 53/53 [==============================] - 0s 5ms/step - loss: 0.0157 - binary_accuracy: 0.9954
# Epoch 27/50
# 53/53 [==============================] - 0s 6ms/step - loss: 0.0139 - binary_accuracy: 0.9959
# Epoch 28/50
# 53/53 [==============================] - 0s 6ms/step - loss: 0.0122 - binary_accuracy: 0.9962
# Epoch 29/50
# 53/53 [==============================] - 0s 6ms/step - loss: 0.0111 - binary_accuracy: 0.9965
# Epoch 30/50
# 53/53 [==============================] - 0s 6ms/step - loss: 0.0100 - binary_accuracy: 0.9968
# Epoch 31/50
# 53/53 [==============================] - 0s 6ms/step - loss: 0.0093 - binary_accuracy: 0.9969
# Epoch 32/50
# 53/53 [==============================] - 0s 5ms/step - loss: 0.0086 - binary_accuracy: 0.9972
# Epoch 33/50
# 53/53 [==============================] - 0s 6ms/step - loss: 0.0080 - binary_accuracy: 0.9974
# Epoch 34/50
# 53/53 [==============================] - 0s 6ms/step - loss: 0.0076 - binary_accuracy: 0.9976
# Epoch 35/50
# 53/53 [==============================] - 0s 6ms/step - loss: 0.0072 - binary_accuracy: 0.9975
# Epoch 36/50
# 53/53 [==============================] - 0s 7ms/step - loss: 0.0067 - binary_accuracy: 0.9977
# Epoch 37/50
# 53/53 [==============================] - 0s 7ms/step - loss: 0.0065 - binary_accuracy: 0.9977
# Epoch 38/50
# 53/53 [==============================] - 0s 8ms/step - loss: 0.0063 - binary_accuracy: 0.9974
# Epoch 39/50
# 53/53 [==============================] - 0s 7ms/step - loss: 0.0062 - binary_accuracy: 0.9978
# Epoch 40/50
# 53/53 [==============================] - 0s 7ms/step - loss: 0.0058 - binary_accuracy: 0.9976
# Epoch 41/50
# 53/53 [==============================] - 0s 7ms/step - loss: 0.0057 - binary_accuracy: 0.9979
# Epoch 42/50
# 53/53 [==============================] - 0s 7ms/step - loss: 0.0056 - binary_accuracy: 0.9977
# Epoch 43/50
# 53/53 [==============================] - 0s 6ms/step - loss: 0.0052 - binary_accuracy: 0.9981
# Epoch 44/50
# 53/53 [==============================] - 0s 6ms/step - loss: 0.0052 - binary_accuracy: 0.9977
# Epoch 45/50
# 53/53 [==============================] - 0s 7ms/step - loss: 0.0054 - binary_accuracy: 0.9977
# Epoch 46/50
# 53/53 [==============================] - 0s 5ms/step - loss: 0.0051 - binary_accuracy: 0.9980
# Epoch 47/50
# 53/53 [==============================] - 0s 6ms/step - loss: 0.0052 - binary_accuracy: 0.9977
# Epoch 48/50
# 53/53 [==============================] - 0s 6ms/step - loss: 0.0050 - binary_accuracy: 0.9980
# Epoch 49/50
# 53/53 [==============================] - 0s 7ms/step - loss: 0.0050 - binary_accuracy: 0.9979
# Epoch 50/50
# 53/53 [==============================] - 0s 7ms/step - loss: 0.0050 - binary_accuracy: 0.9978
# 362/362 [==============================] - 1s 2ms/step - loss: 1.4435 - binary_accuracy: 0.8855
# Epoch 1/50
# 53/53 [==============================] - 2s 46ms/step - loss: 0.4616 - binary_accuracy: 0.8439
# Epoch 2/50
# 53/53 [==============================] - 1s 14ms/step - loss: 0.3565 - binary_accuracy: 0.8594
# Epoch 3/50
# 53/53 [==============================] - 0s 7ms/step - loss: 0.3262 - binary_accuracy: 0.8636
# Epoch 4/50
# 53/53 [==============================] - 0s 7ms/step - loss: 0.3057 - binary_accuracy: 0.8705
# Epoch 5/50
# 53/53 [==============================] - 0s 7ms/step - loss: 0.2865 - binary_accuracy: 0.8819
# Epoch 6/50
# 53/53 [==============================] - 0s 7ms/step - loss: 0.2665 - binary_accuracy: 0.8920
# Epoch 7/50
# 53/53 [==============================] - 0s 7ms/step - loss: 0.2453 - binary_accuracy: 0.9024
# Epoch 8/50
# 53/53 [==============================] - 0s 7ms/step - loss: 0.2227 - binary_accuracy: 0.9134
# Epoch 9/50
# 53/53 [==============================] - 0s 7ms/step - loss: 0.1995 - binary_accuracy: 0.9254
# Epoch 10/50
# 53/53 [==============================] - 0s 7ms/step - loss: 0.1780 - binary_accuracy: 0.9351
# Epoch 11/50
# 53/53 [==============================] - 0s 7ms/step - loss: 0.1549 - binary_accuracy: 0.9456
# Epoch 12/50
# 53/53 [==============================] - 0s 7ms/step - loss: 0.1331 - binary_accuracy: 0.9544
# Epoch 13/50
# 53/53 [==============================] - 0s 7ms/step - loss: 0.1111 - binary_accuracy: 0.9646
# Epoch 14/50
# 53/53 [==============================] - 0s 7ms/step - loss: 0.0925 - binary_accuracy: 0.9721
# Epoch 15/50
# 53/53 [==============================] - 0s 8ms/step - loss: 0.0761 - binary_accuracy: 0.9772
# Epoch 16/50
# 53/53 [==============================] - 0s 7ms/step - loss: 0.0598 - binary_accuracy: 0.9826
# Epoch 17/50
# 53/53 [==============================] - 0s 7ms/step - loss: 0.0476 - binary_accuracy: 0.9860
# Epoch 18/50
# 53/53 [==============================] - 0s 6ms/step - loss: 0.0380 - binary_accuracy: 0.9895
# Epoch 19/50
# 53/53 [==============================] - 0s 6ms/step - loss: 0.0292 - binary_accuracy: 0.9926
# Epoch 20/50
# 53/53 [==============================] - 0s 7ms/step - loss: 0.0238 - binary_accuracy: 0.9937
# Epoch 21/50
# 53/53 [==============================] - 0s 7ms/step - loss: 0.0184 - binary_accuracy: 0.9953
# Epoch 22/50
# 53/53 [==============================] - 0s 7ms/step - loss: 0.0156 - binary_accuracy: 0.9960
# Epoch 23/50
# 53/53 [==============================] - 0s 7ms/step - loss: 0.0123 - binary_accuracy: 0.9973
# Epoch 24/50
# 53/53 [==============================] - 0s 7ms/step - loss: 0.0107 - binary_accuracy: 0.9973
# Epoch 25/50
# 53/53 [==============================] - 0s 7ms/step - loss: 0.0106 - binary_accuracy: 0.9976
# Epoch 26/50
# 53/53 [==============================] - 0s 7ms/step - loss: 0.0078 - binary_accuracy: 0.9980
# Epoch 27/50
# 53/53 [==============================] - 0s 7ms/step - loss: 0.0067 - binary_accuracy: 0.9980
# Epoch 28/50
# 53/53 [==============================] - 0s 7ms/step - loss: 0.0062 - binary_accuracy: 0.9983
# Epoch 29/50
# 53/53 [==============================] - 0s 6ms/step - loss: 0.0066 - binary_accuracy: 0.9983
# Epoch 30/50
# 53/53 [==============================] - 0s 7ms/step - loss: 0.0051 - binary_accuracy: 0.9983
# Epoch 31/50
# 53/53 [==============================] - 0s 7ms/step - loss: 0.0050 - binary_accuracy: 0.9983
# Epoch 32/50
# 53/53 [==============================] - 0s 7ms/step - loss: 0.0046 - binary_accuracy: 0.9985
# Epoch 33/50
# 53/53 [==============================] - 0s 7ms/step - loss: 0.0047 - binary_accuracy: 0.9986
# Epoch 34/50
# 53/53 [==============================] - 0s 7ms/step - loss: 0.0044 - binary_accuracy: 0.9987
# Epoch 35/50
# 53/53 [==============================] - 0s 7ms/step - loss: 0.0039 - binary_accuracy: 0.9985
# Epoch 36/50
# 53/53 [==============================] - 0s 6ms/step - loss: 0.0040 - binary_accuracy: 0.9986
# Epoch 37/50
# 53/53 [==============================] - 0s 6ms/step - loss: 0.0040 - binary_accuracy: 0.9986
# Epoch 38/50
# 53/53 [==============================] - 0s 6ms/step - loss: 0.0039 - binary_accuracy: 0.9986
# Epoch 39/50
# 53/53 [==============================] - 0s 6ms/step - loss: 0.0046 - binary_accuracy: 0.9987
# Epoch 40/50
# 53/53 [==============================] - 0s 7ms/step - loss: 0.0037 - binary_accuracy: 0.9986
# Epoch 41/50
# 53/53 [==============================] - 0s 7ms/step - loss: 0.0034 - binary_accuracy: 0.9986
# Epoch 42/50
# 53/53 [==============================] - 0s 7ms/step - loss: 0.0053 - binary_accuracy: 0.9989
# Epoch 43/50
# 53/53 [==============================] - 0s 7ms/step - loss: 0.0036 - binary_accuracy: 0.9986
# Epoch 44/50
# 53/53 [==============================] - 0s 7ms/step - loss: 0.0036 - binary_accuracy: 0.9986
# Epoch 45/50
# 53/53 [==============================] - 0s 7ms/step - loss: 0.0037 - binary_accuracy: 0.9986
# Epoch 46/50
# 53/53 [==============================] - 0s 6ms/step - loss: 0.0035 - binary_accuracy: 0.9986
# Epoch 47/50
# 53/53 [==============================] - 0s 6ms/step - loss: 0.0034 - binary_accuracy: 0.9986
# Epoch 48/50
# 53/53 [==============================] - 0s 6ms/step - loss: 0.0036 - binary_accuracy: 0.9985
# Epoch 49/50
# 53/53 [==============================] - 0s 7ms/step - loss: 0.0036 - binary_accuracy: 0.9985
# Epoch 50/50
# 53/53 [==============================] - 0s 6ms/step - loss: 0.0035 - binary_accuracy: 0.9985
# 362/362 [==============================] - 1s 1ms/step - loss: 3.1044 - binary_accuracy: 0.7736

# %%
predict("내가 키우던 강아지가 오늘 죽었어...")
# Out:
# 공포(0%)
# 혐오(0%)
# 슬픔(100%)
# 행복(0%)
# 분노(0%)
# 중립(0%)
# 놀람(0%)
